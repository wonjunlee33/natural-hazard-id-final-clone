# %% [markdown]
# # Llama2 working on CS Cluster machines for increased speed (and accuracy)
# Use to run on CS Cluster / locally.

# %% [markdown]
# ## Step 0: Make sure Nvidia RTX is running.

# %%
# check for nvidia CUDA
# !nvidia-smi
# Out:
# Tue Feb 27 01:27:37 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.54.03              Driver Version: 535.54.03    CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 3090 Ti     On  | 00000000:01:00.0 Off |                  Off |
# |  0%   46C    P8              13W / 450W |     28MiB / 24564MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A      2844      G   /usr/libexec/Xorg                             9MiB |
# |    0   N/A  N/A      3056      G   /usr/bin/gnome-shell                          8MiB |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# ## Step 1: Assuming that folder "models" exists, set up Llama2 using ctransformers
# This version of Llama-13b-chat is quantised down to 5 bits for enhanced accuracy.

# %%
# load ctransformers and set up parameters
from ctransformers import AutoModelForCausalLM
llm = AutoModelForCausalLM.from_pretrained(
    model_path_or_repo_id="./models/13B-chat-GGUF-q5_K_M.gguf",
    model_file="13B-chat-GGUF-q5_K_M.gguf",
    model_type="llama",
    max_new_tokens=75,
    repetition_penalty=1.2,
    temperature=0.25,
    top_p=0.95,
    top_k=150,
    threads=22,
    batch_size=40,
    gpu_layers=50,
)

# %% [markdown]
# ## Step 2: Load Excel Spreadsheet and make into a DataFrame.

# %%
import pandas as pd
import os
import re

# specify the path to Excel file
excel_file_path = '../data/hazard_definitions.xlsx'

# read the Excel file into a pandas DataFrame
df = pd.read_excel(excel_file_path)
# Out:
# /tmp/ipykernel_9916/2125124799.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df
# Out:
#     Hazard_Code                  Hazard_Category  Hazard_Subcategory  \
# 0        MH0001  METEOROLOGICAL AND HYDROLOGICAL  Convective-Related
# 1        MH0002  METEOROLOGICAL AND HYDROLOGICAL  Convective-Related
# 2        MH0003  METEOROLOGICAL AND HYDROLOGICAL  Convective-Related
# 3        MH0004  METEOROLOGICAL AND HYDROLOGICAL               Flood
# 4        MH0005  METEOROLOGICAL AND HYDROLOGICAL               Flood
# ..          ...                              ...                 ...
# 297      SO0004                         SOCIETAL       Post-Conflict
# 298      SO0005                         SOCIETAL       Post-Conflict
# 299      SO0006                         SOCIETAL         Behavioural
# 300      SO0007                         SOCIETAL         Behavioural
# 301      SO0008                         SOCIETAL            Economic
#
#                                  Hazard_Name  \
# 0                                  Downburst
# 1               Lightning (Electrical Storm)
# 2                               Thunderstorm
# 3                              Coastal Flood
# 4                  Estuarine (Coastal) Flood
# ..                                       ...
# 297                Explosive Remnants of War
# 298  Environmental Degradation from Conflict
# 299                                 Violence
# 300             Stampede or Crushing (Human)
# 301                          Financial shock
#
#                                     Hazard_Description Upstream_Hazards  \
# 0    Downburst A downburst is a violent and damagin...              NaN
# 1    Lightning Lightning is the luminous manifestat...              NaN
# 2    Thunderstorm A thunderstorm is defined as one ...           MH0002
# 3    Coastal Flood Coastal flooding is most frequen...              NaN
# 4    Estuarine Flood Estuarine flooding is flooding...           MH0004
# ..                                                 ...              ...
# 297  Explosive Remnants of War Explosive remnants o...           SO0003
# 298  Environmental Degradation from Conflict Enviro...           SO0003
# 299  Violence Violence refers to the intentional or...           SO0003
# 300  Stampede or Crushing Stampede or crushing is t...           SO0003
# 301  Financial shock A financial shock is an unexpe...           SO0003
#
#     Excluded_Hazards                                           Synonyms  \
# 0                NaN                  Microburst, Macroburst, Wind Sear
# 1                NaN  Bolt, Thunderbolt, Bolt-from-the-blue, Firebol...
# 2                NaN                                                NaN
# 3                NaN                    Storm Surge, Coastal inundation
# 4                NaN                  Flood, Flooding, Coastal flooding
# ..               ...                                                ...
# 297              NaN  Unexploded ordnance, Abandoned explosive ordnance
# 298              NaN       Ecological degradation, Environmental damage
# 299              NaN                                                NaN
# 300              NaN                  Crush, Mass panic, Crowd disaster
# 301              NaN  Financial crisis, Bank run, Banking crisis, Cu...
#
#                      Keywords Keywords_Operator  \
# 0                        Wind                OR
# 1            Lightning, storm                OR
# 2                       storm                OR
# 3                       Flood                OR
# 4                       river                OR
# ..                        ...               ...
# 297  explosive, crater, mines               AND
# 298            pollution, war               AND
# 299                  violence                OR
# 300        stampede, crushing                OR
# 301  financial, poor, economy                OR
#
#                                              Questions
# 0                               Did a downburst occur?
# 1                                 Was there lightning?
# 2                            Was there a thunderstorm?
# 3                Did the even take place at the coast?
# 4    Was the river flooding caused by coastal flood...
# ..                                                 ...
# 297  Were there any reports of explosive remnants o...
# 298  Were there any reports of environmental degrad...
# 299                Were there any reports of violence?
# 300    Were there any reports of stampede or crushing?
# 301  Were there any reports of financial shock, suc...
#
# [302 rows x 11 columns]

# %% [markdown]
# ## Step 3: Define some helper functions to output correct scores.

# %%
def extract_score(response):
    """
    Extracts the likelihood score from the user's response.

    Parameters:
    response (str): The user's response.

    Returns:
    float: The extracted likelihood score if found, -1 otherwise.
    """
    user_input = response

    # use regular expression to extract the number between 0 and 5"
    likelihood_match = re.search(r'\b([0-5]|\([0-5]\))\b', user_input)

    # check if a match is found and print the extracted number
    if likelihood_match:
        extracted_likelihood = float(likelihood_match.group(1) or likelihood_match.group(2))
        print("Extracted Likelihood:", extracted_likelihood)
        return extracted_likelihood
    else:
        print("No likelihood score found.")
        return -1

# %% [markdown]
# ## Step 4: Create ~ 303^2 combinations and feed through to LLM model.

# %%
# take combinations
from itertools import product

# extracting unique values from the desired column
unique_values = df['Hazard_Name'].unique() # change to create AxA matrix, remove to make all
print(unique_values)

# create double-sided pairs without pairs with the same element
pairs = [(x, y) for x, y in product(unique_values, unique_values) if x != y]
# Out:
# ['Downburst' 'Lightning (Electrical Storm)' 'Thunderstorm' 'Coastal Flood'
#  'Estuarine (Coastal) Flood' 'Flash Flood' 'Fluvial (Riverine) Flood'
#  'Groundwater Flood' 'Ice-Jam Flood Including Debris'
#  'Ponding (Drainage) Flood' 'Snowmelt Flood' 'Surface Water Flooding'
#  'Glacial Lake Outburst Flood' 'Black Carbon (Brown Clouds)'
#  'Dust storm or Sandstorm' 'Fog' 'Haze' 'Polluted Air' 'Sand haze' 'Smoke'
#  'Ocean Acidification' 'Rogue Wave' 'Sea Water Intrusion'
#  'Sea Ice (Ice Bergs)' 'Ice Flow' 'Seiche' 'Storm Surge' 'Storm Tides'
#  'Tsunami' 'Depression or Cyclone (Low Pressure Area)'
#  'Extra-tropical Cyclone' 'Sub-Tropical Cyclone' 'Acid Rain' 'Blizzard'
#  'Drought' 'Hail' 'Ice Storm' 'Snow' 'Snow Storm' 'Cold Wave' 'Dzud'
#  'Freeze' 'Frost (Hoar Frost)' 'Freezing Rain (Supercooled Rain)' 'Glaze'
#  'Ground Frost' 'Heatwave' 'Icing (Including Ice)' 'Thaw' 'Avalanche'
#  'Mud Flow' 'Rock slide' 'Derecho' 'Gale (Strong Gale)' 'Squall'
#  'Subtropical Storm' 'Tropical Cyclone (Cyclonic Wind/ Rain Storm Surge)'
#  'Tropical Storm' 'Tornado' 'Wind' 'Airburst'
#  'Geomagnetic Storm (including energetic particles related to space weather, and solar flare radio blackout [R Scale])'
#  'UV Radiation' 'Meteorite Impact' 'Ionospheric Storms' 'Radio Blackout'
#  'Solar Storm (Solar Radiation Storm) (S Scale)' 'Space Hazard / Accident'
#  'Near-Earth Object' 'Earthquake' 'Ground Shaking (Earthquake)'
#  'Liquefaction (Earthquake Trigger)'
#  'Earthquake Surface Rupture, Fissures, and Tectonic Uplift/Subsidence'
#  'Subsidance and Uplift, Including Shoreline Change (Earthquake Trigger)'
#  'Tsunami (Earthquake Trigger)'
#  'Landslide or Debris Flow (Earthquake trigger)'
#  'Ground Gases (Seismogenic)' 'Lava Flows (Lava Domes)'
#  'Ash/Tephra Fall (Physical and Chemical)' 'Ballistics (Volcanic)'
#  'Pyroclastic Density Current' 'Debris Flow/Lahars/Floods'
#  'Landslide (Volcanic Trigger)' 'Ground Shaking (Volcanic Earthquake)'
#  'Volcanic Gases and Aerosols' 'Tsunami (Volcanic Trigger)'
#  'Lightning (Volcanic Trigger)'
#  'Urban Fire (During/Following Volcanic Eruption)'
#  'Subsidence and Uplift, Including Shoreline Change (Magmatic/Volcanic Trigger)'
#  'Ground Shaking (induced earthquake, reservoir fill, dams, cavity collapse, underground explosion, impact, hydrocarbon fields, shale exploration, etc.)'
#  'Liquefaction (Groundwater Trigger)' 'Ground Fissuring'
#  'Subsidence and Uplift Including Shoreline Change'
#  'Shrink-Swell Subsidence' 'Sinkhole' 'Ground Gases (CH4, Rn, etc.)'
#  'Riverbank Erosion' 'Sand Encroachment'
#  'Aquifer Recharge (Systems Failure/ Outages)' 'Submarine Landslide'
#  'Rockfall' 'Landscape Creep' 'Sediment Rock Avalanche'
#  'Tsunami (Submarine Landslide Trigger)' 'Household Air Pollution'
#  'Air Pollution (Point Source)' 'Ambient (Outdoor) Air Pollution'
#  'Land Degradation' 'Soil Degradation'
#  'Runoff / Nonpoint Source Pollution' 'Salinity' 'Biodiversity Loss'
#  'Deforestation' 'Forest Declines and Diebacks' 'Forest Disturbances'
#  'Forest Invasive Species' 'Wildfires' 'Desertification'
#  'Loss of Mangroves' 'Wetland Loss/Degradation' 'Coral Bleaching'
#  'Compressive Soils' 'Soil Erosion' 'Coastal Erosion and Shoreline Change'
#  'Permafrost Loss' 'Sand Mining' 'Sea Level Rise' 'Eutrophication'
#  'Ammonia' 'Carbon Monoxide' 'Arsenic' 'Cadmium' 'Lead' 'Mercury'
#  'Levels of Contaminants in Food and Feed' 'Pesticides – Highly Hazardous'
#  'Residue of Pesticides' 'Hazardous Pesticide Contamination in Soils'
#  'Insecticides' 'Fungicides' 'Dioxins and Dioxin-like Substances'
#  'Microplastics' 'Phosphine' 'Chlorine' 'Oil Pollution' 'Benzene'
#  'Chemical Warfare Agents' 'Asbestos' 'Aflatoxins'
#  'Fluoride - Excess or inadequate intake' 'Methanol'
#  'Substandard and Falsified Medical Products' 'Marine Toxins'
#  'Harmful Algal Blooms' 'Insect Pest Infestations' 'Locust'
#  'Invasive Weeds' 'Invasive Species' 'Snake Envenomation'
#  'Human-Wildlife Conflict' 'Biological Agents' 'Suicide Cluster'
#  'Antimicrobial Resistance'
#  'Foodborne Microbial Hazards (including human enteric virus and foodborne parasite)'
#  'Bacterial Plant Disease' 'Fungal Plant Disease'
#  'Viral, Mycoplasma and Viroid Plant Disease Epidemics' 'Anthrax'
#  'Airborne Diseases' 'Blood Borne Viruses' 'Waterborne Diseases'
#  'Foodborne Diseases' 'Sexually Transmitted Diseases (Human)'
#  'Neglected Tropical Diseases (Human)'
#  'Vaccine-Preventable Diseases (Human)'
#  'Vector Borne Diseases (VBD) (Human)' 'Viral Haemorrhagic Fevers (Human)'
#  'Antimicrobial Resistant Microorganisms (Human)'
#  'Animal Diseases (Not Zoonoses)' 'Zoonotic Diseases'
#  'Diarrhoeal Diseases (Human)' 'Prion Diseases' 'Hepatitis B (Human)'
#  'Hepatitis C (human)' 'HIV and AIDS (Human)'
#  'COVID-19 (SARS-CoV-2) (Human)' 'Cholera (Human)'
#  'Cryptosporidium (Human)' 'Paratyphoid fever (Human)'
#  'Typhoid Fever (Human)' 'Hepatitis A (Human)'
#  'Escherichia Coli (STEC) (Human)' 'Listeriosis (Human)'
#  'Shigellosis (Human)' 'Avian Influenza (Human and Animal)'
#  'Pandemic Influenza (Human)' 'Seasonal Influenza (Human)' 'Cysticercosis'
#  'Leptospirosis (Human)' 'Plague (Human)' 'Leprosy' 'Chikungunya'
#  'Zika Virus (human)' 'Diphtheria (Human)' 'Measles (Human)'
#  'Meningococcal Meningitis (Human)' 'Pertussis (Human)' 'Polio (Human)'
#  'Smallpox (Human)' 'Varicella and herpes zoster (Human)'
#  'Yellow Fever (Human)' 'Dengue (Human)' 'Malaria (Human)'
#  'Crimean-Congo Haemorrhagic Fever (Human)' 'Ebola (Human)'
#  'Lassa Fever (Human)' 'Tuberculosis (Human and Animal)'
#  'Middle East Respiratory Syndrome (MERS) (Human)' 'Monkeypox (Human)'
#  'Rabies (Animal and Human)'
#  'Severe Acute Respiratory Syndrome (SARS) (Human)' 'Rotavirus (Human)'
#  'African Swine Fever (Animal)' 'Vector-borne diseases (VBD) (Animals)'
#  'Brucellosis (Animal)' 'Classical Swine Fever (Animal)'
#  'Contagious Bovine Pleuropneumonia (CBPP) (Animal)'
#  'Contagious Caprine Pleuropneumonia (CCPP) (Animal)'
#  'Foot and Mouth Disease Virus (Animal)' 'Lumpy Skin Disease (Animal)'
#  'New World Screwworm (NWS) (Animal)' 'Newcastle Disease Virus (Animal)'
#  'Peste Des Petits Ruminants (Animal)' 'Q Fever'
#  'Rift Valley Fever (Animal)' 'Trypanosomosis (Animal)'
#  'West Nile Fever (Human)' 'Rinderpest (Animal)' 'Trypanosomiasis (Human)'
#  'Shrimp disease (bacterial) - Acute Hepatic pancreatic necrosis'
#  'Oyster Disease Aquaculture' 'Radioactive Waste' 'Radioactive Material'
#  'Radiation Agents' 'Nuclear Agents' 'Building Collapse'
#  'Building, highrise, cladding' 'Structural Failure' 'Bridge Failure'
#  'Dam Failure' 'Supply Chain Failure' 'Critical Infrastructure Failure'
#  'Nuclear Plant Failure' 'Power Outage/ or Blackout'
#  'Emergency Telecommunications Failure' 'Water Supply Failure'
#  'Radio and Other Telecommunication Failures'
#  'Misconfiguration of Software and Hardware'
#  'Non-Conformity and Interoperability' 'Malware' 'Data Breach'
#  'Data Security-Related Hazards' 'Disrupt' 'Outage'
#  'Personally Identifiable Information (PII) Breach'
#  'Internet of Things (IOT)-Related Hazards' 'Cyberbullying' 'Natech'
#  'Pollution' 'Explosion' 'Leaks and Spills' 'Soil Pollution' 'Fire'
#  'Mining Hazards'
#  'Safety Hazards Associated with Oil and Gas Extraction Activities'
#  'Disaster Waste' 'Solid Waste' 'Wastewater' 'Hazardous Waste'
#  'Plastic Waste' 'Marine Debris' 'Electronic Waste (E-Waste)'
#  'Healthcare Risk Waste' 'Landfilling' 'Tailings'
#  'Waste Treatment Lagoons' 'Drain and Sewer Flooding' 'Reservoir Flooding'
#  'Air Transportation Accident' 'Inland Water Ways' 'Marine Accident'
#  'Rail Accident' 'Road Traffic Accident' 'Explosive agents'
#  'International Armed Conflict (IAC)'
#  'Non-International Armed Conflict (NIAC)' 'Civil Unrest'
#  'Explosive Remnants of War' 'Environmental Degradation from Conflict'
#  'Violence' 'Stampede or Crushing (Human)' 'Financial shock']

# %% [markdown]
# ## Step 5: Create new dataframes to store new data.

# %%
# Check if the excel files already exist
if os.path.exists("./out/scores.xlsx") and os.path.exists("./out/justifications.xlsx"):
    # Load the existing excel files
    scores_df = pd.read_excel("./out/scores.xlsx", index_col=0, dtype=str)
    justification_df = pd.read_excel("./out/justifications.xlsx", index_col=0, dtype=str)
else:
    # Create new excel files
    # print("poo")
    scores_df = pd.DataFrame(index=unique_values, columns=unique_values)
    justification_df = pd.DataFrame(index=unique_values, columns=unique_values)

scores_df
# Out:
#                                         Downburst  \
# Downburst                                     NaN
# Lightning (Electrical Storm)                  NaN
# Thunderstorm                                  NaN
# Coastal Flood                                 NaN
# Estuarine (Coastal) Flood                     NaN
# ...                                           ...
# Explosive Remnants of War                     NaN
# Environmental Degradation from Conflict       NaN
# Violence                                      NaN
# Stampede or Crushing (Human)                  NaN
# Financial shock                               NaN
#
#                                         Lightning (Electrical Storm)  \
# Downburst                                                         -1
# Lightning (Electrical Storm)                                     NaN
# Thunderstorm                                                     NaN
# Coastal Flood                                                    NaN
# Estuarine (Coastal) Flood                                        NaN
# ...                                                              ...
# Explosive Remnants of War                                        NaN
# Environmental Degradation from Conflict                          NaN
# Violence                                                         NaN
# Stampede or Crushing (Human)                                     NaN
# Financial shock                                                  NaN
#
#                                         Thunderstorm Coastal Flood  \
# Downburst                                         -1            -1
# Lightning (Electrical Storm)                     NaN           NaN
# Thunderstorm                                     NaN           NaN
# Coastal Flood                                    NaN           NaN
# Estuarine (Coastal) Flood                        NaN           NaN
# ...                                              ...           ...
# Explosive Remnants of War                        NaN           NaN
# Environmental Degradation from Conflict          NaN           NaN
# Violence                                         NaN           NaN
# Stampede or Crushing (Human)                     NaN           NaN
# Financial shock                                  NaN           NaN
#
#                                         Estuarine (Coastal) Flood Flash Flood  \
# Downburst                                                      -1          -1
# Lightning (Electrical Storm)                                  NaN         NaN
# Thunderstorm                                                  NaN         NaN
# Coastal Flood                                                 NaN         NaN
# Estuarine (Coastal) Flood                                     NaN         NaN
# ...                                                           ...         ...
# Explosive Remnants of War                                     NaN         NaN
# Environmental Degradation from Conflict                       NaN         NaN
# Violence                                                      NaN         NaN
# Stampede or Crushing (Human)                                  NaN         NaN
# Financial shock                                               NaN         NaN
#
#                                         Fluvial (Riverine) Flood  \
# Downburst                                                     -1
# Lightning (Electrical Storm)                                 NaN
# Thunderstorm                                                 NaN
# Coastal Flood                                                NaN
# Estuarine (Coastal) Flood                                    NaN
# ...                                                          ...
# Explosive Remnants of War                                    NaN
# Environmental Degradation from Conflict                      NaN
# Violence                                                     NaN
# Stampede or Crushing (Human)                                 NaN
# Financial shock                                              NaN
#
#                                         Groundwater Flood  \
# Downburst                                              -1
# Lightning (Electrical Storm)                          NaN
# Thunderstorm                                          NaN
# Coastal Flood                                         NaN
# Estuarine (Coastal) Flood                             NaN
# ...                                                   ...
# Explosive Remnants of War                             NaN
# Environmental Degradation from Conflict               NaN
# Violence                                              NaN
# Stampede or Crushing (Human)                          NaN
# Financial shock                                       NaN
#
#                                         Ice-Jam Flood Including Debris  \
# Downburst                                                           -1
# Lightning (Electrical Storm)                                       NaN
# Thunderstorm                                                       NaN
# Coastal Flood                                                      NaN
# Estuarine (Coastal) Flood                                          NaN
# ...                                                                ...
# Explosive Remnants of War                                          NaN
# Environmental Degradation from Conflict                            NaN
# Violence                                                           NaN
# Stampede or Crushing (Human)                                       NaN
# Financial shock                                                    NaN
#
#                                         Ponding (Drainage) Flood  ...  \
# Downburst                                                     -1  ...
# Lightning (Electrical Storm)                                 NaN  ...
# Thunderstorm                                                 NaN  ...
# Coastal Flood                                                NaN  ...
# Estuarine (Coastal) Flood                                    NaN  ...
# ...                                                          ...  ...
# Explosive Remnants of War                                    NaN  ...
# Environmental Degradation from Conflict                      NaN  ...
# Violence                                                     NaN  ...
# Stampede or Crushing (Human)                                 NaN  ...
# Financial shock                                              NaN  ...
#
#                                         Road Traffic Accident  \
# Downburst                                                 NaN
# Lightning (Electrical Storm)                              NaN
# Thunderstorm                                              NaN
# Coastal Flood                                             NaN
# Estuarine (Coastal) Flood                                 NaN
# ...                                                       ...
# Explosive Remnants of War                                 NaN
# Environmental Degradation from Conflict                   NaN
# Violence                                                  NaN
# Stampede or Crushing (Human)                              NaN
# Financial shock                                           NaN
#
#                                         Explosive agents  \
# Downburst                                            NaN
# Lightning (Electrical Storm)                         NaN
# Thunderstorm                                         NaN
# Coastal Flood                                        NaN
# Estuarine (Coastal) Flood                            NaN
# ...                                                  ...
# Explosive Remnants of War                            NaN
# Environmental Degradation from Conflict              NaN
# Violence                                             NaN
# Stampede or Crushing (Human)                         NaN
# Financial shock                                      NaN
#
#                                         International Armed Conflict (IAC)  \
# Downburst                                                              NaN
# Lightning (Electrical Storm)                                           NaN
# Thunderstorm                                                           NaN
# Coastal Flood                                                          NaN
# Estuarine (Coastal) Flood                                              NaN
# ...                                                                    ...
# Explosive Remnants of War                                              NaN
# Environmental Degradation from Conflict                                NaN
# Violence                                                               NaN
# Stampede or Crushing (Human)                                           NaN
# Financial shock                                                        NaN
#
#                                         Non-International Armed Conflict (NIAC)  \
# Downburst                                                                   NaN
# Lightning (Electrical Storm)                                                NaN
# Thunderstorm                                                                NaN
# Coastal Flood                                                               NaN
# Estuarine (Coastal) Flood                                                   NaN
# ...                                                                         ...
# Explosive Remnants of War                                                   NaN
# Environmental Degradation from Conflict                                     NaN
# Violence                                                                    NaN
# Stampede or Crushing (Human)                                                NaN
# Financial shock                                                             NaN
#
#                                         Civil Unrest  \
# Downburst                                        NaN
# Lightning (Electrical Storm)                     NaN
# Thunderstorm                                     NaN
# Coastal Flood                                    NaN
# Estuarine (Coastal) Flood                        NaN
# ...                                              ...
# Explosive Remnants of War                        NaN
# Environmental Degradation from Conflict          NaN
# Violence                                         NaN
# Stampede or Crushing (Human)                     NaN
# Financial shock                                  NaN
#
#                                         Explosive Remnants of War  \
# Downburst                                                     NaN
# Lightning (Electrical Storm)                                  NaN
# Thunderstorm                                                  NaN
# Coastal Flood                                                 NaN
# Estuarine (Coastal) Flood                                     NaN
# ...                                                           ...
# Explosive Remnants of War                                     NaN
# Environmental Degradation from Conflict                       NaN
# Violence                                                      NaN
# Stampede or Crushing (Human)                                  NaN
# Financial shock                                               NaN
#
#                                         Environmental Degradation from Conflict  \
# Downburst                                                                   NaN
# Lightning (Electrical Storm)                                                NaN
# Thunderstorm                                                                NaN
# Coastal Flood                                                               NaN
# Estuarine (Coastal) Flood                                                   NaN
# ...                                                                         ...
# Explosive Remnants of War                                                   NaN
# Environmental Degradation from Conflict                                     NaN
# Violence                                                                    NaN
# Stampede or Crushing (Human)                                                NaN
# Financial shock                                                             NaN
#
#                                         Violence Stampede or Crushing (Human)  \
# Downburst                                    NaN                          NaN
# Lightning (Electrical Storm)                 NaN                          NaN
# Thunderstorm                                 NaN                          NaN
# Coastal Flood                                NaN                          NaN
# Estuarine (Coastal) Flood                    NaN                          NaN
# ...                                          ...                          ...
# Explosive Remnants of War                    NaN                          NaN
# Environmental Degradation from Conflict      NaN                          NaN
# Violence                                     NaN                          NaN
# Stampede or Crushing (Human)                 NaN                          NaN
# Financial shock                              NaN                          NaN
#
#                                         Financial shock
# Downburst                                           NaN
# Lightning (Electrical Storm)                        NaN
# Thunderstorm                                        NaN
# Coastal Flood                                       NaN
# Estuarine (Coastal) Flood                           NaN
# ...                                                 ...
# Explosive Remnants of War                           NaN
# Environmental Degradation from Conflict             NaN
# Violence                                            NaN
# Stampede or Crushing (Human)                        NaN
# Financial shock                                     NaN
#
# [302 rows x 302 columns]

# %% [markdown]
# ### Step 5.5: Find the first pair which does not have a value stored

# %%
def find_first_missing_pair(df):
    '''
    Finds the first pair of row and column categories in a DataFrame where the corresponding element is missing.

    Parameters:
    - df (pd.DataFrame): The DataFrame to search for missing values.

    Returns:
    - tuple or None: If a missing value is found, returns a tuple containing the row and column categories of the missing element. If no missing values are found, returns None.
    '''
    categories = df.columns  # Exclude the first column which contains row headers
    for i, row_category in enumerate(categories):
        for j, col_category in enumerate(categories):
            if i != j:  # Exclude pairs where both elements are the same
                value = df.iloc[i, j]  # j+1 to account for the row header column
                if pd.isna(value):  # Check if the value is NaN
                    print(i, j)
                    return (row_category, col_category)
    return None

missing_value = find_first_missing_pair(scores_df)
missing_value
# Out:
# 0 22
# ('Downburst', 'Sea Water Intrusion')

# %% [markdown]
# ## Step 6: Run the LLM.

# %%
def run_llm(hazard1, hazard2, def1, def2):
    '''
    Run a likelihood assessment using a Language Model (LLM) to evaluate the likelihood that a given hazard1 causes hazard2.

    Parameters:
    - hazard1 (str): The first hazard in the assessment.
    - hazard2 (str): The second hazard in the assessment.
    - def1 (str): The definition of the first hazard.
    - def2 (str): The definition of the second hazard.

    Returns:
    tuple: A tuple containing the numerical score representing the likelihood assessment (ranging from 0 to 5) and the detailed response from the language model.
    '''
    # cut definitions to be only first sentence
    def1 = def1.split(".")[0]
    def2 = def2.split(".")[0]
    
    # begin prompting
    prompt = f"""What is the likelihood that {hazard1} causes {hazard2}, bearing in mind:
    {hazard1}: {def1}
    {hazard2}: {def2}
    """
    
    super_prompt = f"""
    SYSTEM: We're evaluating the likelihood of various hazards causing specific outcomes. Your responses should be one number between 0 and 5, following the below scale. Include a short explanation for your score, as it helps understand the reasoning behind your assessment.
    
    - 0: Almost never
    - 1: Very Unlikely
    - 2: Unlikely
    - 3: Likely
    - 4: Very likely
    - 5: Almost always

    Given the above, consider the following query:

    USER: {prompt}
    
    ASSISTANT:
    """
    
    response = llm(super_prompt)
    print(f"Running: {hazard1}, {hazard2}")
    print(response)
    score = extract_score(response)
    print("====================================")
    return (score, response)

# %%
pairs
# Out:
# [('Downburst', 'Lightning (Electrical Storm)'),
#  ('Downburst', 'Thunderstorm'),
#  ('Downburst', 'Coastal Flood'),
#  ('Downburst', 'Estuarine (Coastal) Flood'),
#  ('Downburst', 'Flash Flood'),
#  ('Downburst', 'Fluvial (Riverine) Flood'),
#  ('Downburst', 'Groundwater Flood'),
#  ('Downburst', 'Ice-Jam Flood Including Debris'),
#  ('Downburst', 'Ponding (Drainage) Flood'),
#  ('Downburst', 'Snowmelt Flood'),
#  ('Downburst', 'Surface Water Flooding'),
#  ('Downburst', 'Glacial Lake Outburst Flood'),
#  ('Downburst', 'Black Carbon (Brown Clouds)'),
#  ('Downburst', 'Dust storm or Sandstorm'),
#  ('Downburst', 'Fog'),
#  ('Downburst', 'Haze'),
#  ('Downburst', 'Polluted Air'),
#  ('Downburst', 'Sand haze'),
#  ('Downburst', 'Smoke'),
#  ('Downburst', 'Ocean Acidification'),
#  ('Downburst', 'Rogue Wave'),
#  ('Downburst', 'Sea Water Intrusion'),
#  ('Downburst', 'Sea Ice (Ice Bergs)'),
#  ('Downburst', 'Ice Flow'),
#  ('Downburst', 'Seiche'),
#  ('Downburst', 'Storm Surge'),
#  ('Downburst', 'Storm Tides'),
#  ('Downburst', 'Tsunami'),
#  ('Downburst', 'Depression or Cyclone (Low Pressure Area)'),
#  ('Downburst', 'Extra-tropical Cyclone'),
#  ('Downburst', 'Sub-Tropical Cyclone'),
#  ('Downburst', 'Acid Rain'),
#  ('Downburst', 'Blizzard'),
#  ('Downburst', 'Drought'),
#  ('Downburst', 'Hail'),
#  ('Downburst', 'Ice Storm'),
#  ('Downburst', 'Snow'),
#  ('Downburst', 'Snow Storm'),
#  ('Downburst', 'Cold Wave'),
#  ('Downburst', 'Dzud'),
#  ('Downburst', 'Freeze'),
#  ('Downburst', 'Frost (Hoar Frost)'),
#  ('Downburst', 'Freezing Rain (Supercooled Rain)'),
#  ('Downburst', 'Glaze'),
#  ('Downburst', 'Ground Frost'),
#  ('Downburst', 'Heatwave'),
#  ('Downburst', 'Icing (Including Ice)'),
#  ('Downburst', 'Thaw'),
#  ('Downburst', 'Avalanche'),
#  ('Downburst', 'Mud Flow'),
#  ('Downburst', 'Rock slide'),
#  ('Downburst', 'Derecho'),
#  ('Downburst', 'Gale (Strong Gale)'),
#  ('Downburst', 'Squall'),
#  ('Downburst', 'Subtropical Storm'),
#  ('Downburst', 'Tropical Cyclone (Cyclonic Wind/ Rain Storm Surge)'),
#  ('Downburst', 'Tropical Storm'),
#  ('Downburst', 'Tornado'),
#  ('Downburst', 'Wind'),
#  ('Downburst', 'Airburst'),
#  ('Downburst',
#   'Geomagnetic Storm (including energetic particles related to space weather, and solar flare radio blackout [R Scale])'),
#  ('Downburst', 'UV Radiation'),
#  ('Downburst', 'Meteorite Impact'),
#  ('Downburst', 'Ionospheric Storms'),
#  ('Downburst', 'Radio Blackout'),
#  ('Downburst', 'Solar Storm (Solar Radiation Storm) (S Scale)'),
#  ('Downburst', 'Space Hazard / Accident'),
#  ('Downburst', 'Near-Earth Object'),
#  ('Downburst', 'Earthquake'),
#  ('Downburst', 'Ground Shaking (Earthquake)'),
#  ('Downburst', 'Liquefaction (Earthquake Trigger)'),
#  ('Downburst',
#   'Earthquake Surface Rupture, Fissures, and Tectonic Uplift/Subsidence'),
#  ('Downburst',
#   'Subsidance and Uplift, Including Shoreline Change (Earthquake Trigger)'),
#  ('Downburst', 'Tsunami (Earthquake Trigger)'),
#  ('Downburst', 'Landslide or Debris Flow (Earthquake trigger)'),
#  ('Downburst', 'Ground Gases (Seismogenic)'),
#  ('Downburst', 'Lava Flows (Lava Domes)'),
#  ('Downburst', 'Ash/Tephra Fall (Physical and Chemical)'),
#  ('Downburst', 'Ballistics (Volcanic)'),
#  ('Downburst', 'Pyroclastic Density Current'),
#  ('Downburst', 'Debris Flow/Lahars/Floods'),
#  ('Downburst', 'Landslide (Volcanic Trigger)'),
#  ('Downburst', 'Ground Shaking (Volcanic Earthquake)'),
#  ('Downburst', 'Volcanic Gases and Aerosols'),
#  ('Downburst', 'Tsunami (Volcanic Trigger)'),
#  ('Downburst', 'Lightning (Volcanic Trigger)'),
#  ('Downburst', 'Urban Fire (During/Following Volcanic Eruption)'),
#  ('Downburst',
#   'Subsidence and Uplift, Including Shoreline Change (Magmatic/Volcanic Trigger)'),
#  ('Downburst',
#   'Ground Shaking (induced earthquake, reservoir fill, dams, cavity collapse, underground explosion, impact, hydrocarbon fields, shale exploration, etc.)'),
#  ('Downburst', 'Liquefaction (Groundwater Trigger)'),
#  ('Downburst', 'Ground Fissuring'),
#  ('Downburst', 'Subsidence and Uplift Including Shoreline Change'),
#  ('Downburst', 'Shrink-Swell Subsidence'),
#  ('Downburst', 'Sinkhole'),
#  ('Downburst', 'Ground Gases (CH4, Rn, etc.)'),
#  ('Downburst', 'Riverbank Erosion'),
#  ('Downburst', 'Sand Encroachment'),
#  ('Downburst', 'Aquifer Recharge (Systems Failure/ Outages)'),
#  ('Downburst', 'Submarine Landslide'),
#  ('Downburst', 'Rockfall'),
#  ('Downburst', 'Landscape Creep'),
#  ('Downburst', 'Sediment Rock Avalanche'),
#  ('Downburst', 'Tsunami (Submarine Landslide Trigger)'),
#  ('Downburst', 'Household Air Pollution'),
#  ('Downburst', 'Air Pollution (Point Source)'),
#  ('Downburst', 'Ambient (Outdoor) Air Pollution'),
#  ('Downburst', 'Land Degradation'),
#  ('Downburst', 'Soil Degradation'),
#  ('Downburst', 'Runoff / Nonpoint Source Pollution'),
#  ('Downburst', 'Salinity'),
#  ('Downburst', 'Biodiversity Loss'),
#  ('Downburst', 'Deforestation'),
#  ('Downburst', 'Forest Declines and Diebacks'),
#  ('Downburst', 'Forest Disturbances'),
#  ('Downburst', 'Forest Invasive Species'),
#  ('Downburst', 'Wildfires'),
#  ('Downburst', 'Desertification'),
#  ('Downburst', 'Loss of Mangroves'),
#  ('Downburst', 'Wetland Loss/Degradation'),
#  ('Downburst', 'Coral Bleaching'),
#  ('Downburst', 'Compressive Soils'),
#  ('Downburst', 'Soil Erosion'),
#  ('Downburst', 'Coastal Erosion and Shoreline Change'),
#  ('Downburst', 'Permafrost Loss'),
#  ('Downburst', 'Sand Mining'),
#  ('Downburst', 'Sea Level Rise'),
#  ('Downburst', 'Eutrophication'),
#  ('Downburst', 'Ammonia'),
#  ('Downburst', 'Carbon Monoxide'),
#  ('Downburst', 'Arsenic'),
#  ('Downburst', 'Cadmium'),
#  ('Downburst', 'Lead'),
#  ('Downburst', 'Mercury'),
#  ('Downburst', 'Levels of Contaminants in Food and Feed'),
#  ('Downburst', 'Pesticides – Highly Hazardous'),
#  ('Downburst', 'Residue of Pesticides'),
#  ('Downburst', 'Hazardous Pesticide Contamination in Soils'),
#  ('Downburst', 'Insecticides'),
#  ('Downburst', 'Fungicides'),
#  ('Downburst', 'Dioxins and Dioxin-like Substances'),
#  ('Downburst', 'Microplastics'),
#  ('Downburst', 'Phosphine'),
#  ('Downburst', 'Chlorine'),
#  ('Downburst', 'Oil Pollution'),
#  ('Downburst', 'Benzene'),
#  ('Downburst', 'Chemical Warfare Agents'),
#  ('Downburst', 'Asbestos'),
#  ('Downburst', 'Aflatoxins'),
#  ('Downburst', 'Fluoride - Excess or inadequate intake'),
#  ('Downburst', 'Methanol'),
#  ('Downburst', 'Substandard and Falsified Medical Products'),
#  ('Downburst', 'Marine Toxins'),
#  ('Downburst', 'Harmful Algal Blooms'),
#  ('Downburst', 'Insect Pest Infestations'),
#  ('Downburst', 'Locust'),
#  ('Downburst', 'Invasive Weeds'),
#  ('Downburst', 'Invasive Species'),
#  ('Downburst', 'Snake Envenomation'),
#  ('Downburst', 'Human-Wildlife Conflict'),
#  ('Downburst', 'Biological Agents'),
#  ('Downburst', 'Suicide Cluster'),
#  ('Downburst', 'Antimicrobial Resistance'),
#  ('Downburst',
#   'Foodborne Microbial Hazards (including human enteric virus and foodborne parasite)'),
#  ('Downburst', 'Bacterial Plant Disease'),
#  ('Downburst', 'Fungal Plant Disease'),
#  ('Downburst', 'Viral, Mycoplasma and Viroid Plant Disease Epidemics'),
#  ('Downburst', 'Anthrax'),
#  ('Downburst', 'Airborne Diseases'),
#  ('Downburst', 'Blood Borne Viruses'),
#  ('Downburst', 'Waterborne Diseases'),
#  ('Downburst', 'Foodborne Diseases'),
#  ('Downburst', 'Sexually Transmitted Diseases (Human)'),
#  ('Downburst', 'Neglected Tropical Diseases (Human)'),
#  ('Downburst', 'Vaccine-Preventable Diseases (Human)'),
#  ('Downburst', 'Vector Borne Diseases (VBD) (Human)'),
#  ('Downburst', 'Viral Haemorrhagic Fevers (Human)'),
#  ('Downburst', 'Antimicrobial Resistant Microorganisms (Human)'),
#  ('Downburst', 'Animal Diseases (Not Zoonoses)'),
#  ('Downburst', 'Zoonotic Diseases'),
#  ('Downburst', 'Diarrhoeal Diseases (Human)'),
#  ('Downburst', 'Prion Diseases'),
#  ('Downburst', 'Hepatitis B (Human)'),
#  ('Downburst', 'Hepatitis C (human)'),
#  ('Downburst', 'HIV and AIDS (Human)'),
#  ('Downburst', 'COVID-19 (SARS-CoV-2) (Human)'),
#  ('Downburst', 'Cholera (Human)'),
#  ('Downburst', 'Cryptosporidium (Human)'),
#  ('Downburst', 'Paratyphoid fever (Human)'),
#  ('Downburst', 'Typhoid Fever (Human)'),
#  ('Downburst', 'Hepatitis A (Human)'),
#  ('Downburst', 'Escherichia Coli (STEC) (Human)'),
#  ('Downburst', 'Listeriosis (Human)'),
#  ('Downburst', 'Shigellosis (Human)'),
#  ('Downburst', 'Avian Influenza (Human and Animal)'),
#  ('Downburst', 'Pandemic Influenza (Human)'),
#  ('Downburst', 'Seasonal Influenza (Human)'),
#  ('Downburst', 'Cysticercosis'),
#  ('Downburst', 'Leptospirosis (Human)'),
#  ('Downburst', 'Plague (Human)'),
#  ('Downburst', 'Leprosy'),
#  ('Downburst', 'Chikungunya'),
#  ('Downburst', 'Zika Virus (human)'),
#  ('Downburst', 'Diphtheria (Human)'),
#  ('Downburst', 'Measles (Human)'),
#  ('Downburst', 'Meningococcal Meningitis (Human)'),
#  ('Downburst', 'Pertussis (Human)'),
#  ('Downburst', 'Polio (Human)'),
#  ('Downburst', 'Smallpox (Human)'),
#  ('Downburst', 'Varicella and herpes zoster (Human)'),
#  ('Downburst', 'Yellow Fever (Human)'),
#  ('Downburst', 'Dengue (Human)'),
#  ('Downburst', 'Malaria (Human)'),
#  ('Downburst', 'Crimean-Congo Haemorrhagic Fever (Human)'),
#  ('Downburst', 'Ebola (Human)'),
#  ('Downburst', 'Lassa Fever (Human)'),
#  ('Downburst', 'Tuberculosis (Human and Animal)'),
#  ('Downburst', 'Middle East Respiratory Syndrome (MERS) (Human)'),
#  ('Downburst', 'Monkeypox (Human)'),
#  ('Downburst', 'Rabies (Animal and Human)'),
#  ('Downburst', 'Severe Acute Respiratory Syndrome (SARS) (Human)'),
#  ('Downburst', 'Rotavirus (Human)'),
#  ('Downburst', 'African Swine Fever (Animal)'),
#  ('Downburst', 'Vector-borne diseases (VBD) (Animals)'),
#  ('Downburst', 'Brucellosis (Animal)'),
#  ('Downburst', 'Classical Swine Fever (Animal)'),
#  ('Downburst', 'Contagious Bovine Pleuropneumonia (CBPP) (Animal)'),
#  ('Downburst', 'Contagious Caprine Pleuropneumonia (CCPP) (Animal)'),
#  ('Downburst', 'Foot and Mouth Disease Virus (Animal)'),
#  ('Downburst', 'Lumpy Skin Disease (Animal)'),
#  ('Downburst', 'New World Screwworm (NWS) (Animal)'),
#  ('Downburst', 'Newcastle Disease Virus (Animal)'),
#  ('Downburst', 'Peste Des Petits Ruminants (Animal)'),
#  ('Downburst', 'Q Fever'),
#  ('Downburst', 'Rift Valley Fever (Animal)'),
#  ('Downburst', 'Trypanosomosis (Animal)'),
#  ('Downburst', 'West Nile Fever (Human)'),
#  ('Downburst', 'Rinderpest (Animal)'),
#  ('Downburst', 'Trypanosomiasis (Human)'),
#  ('Downburst',
#   'Shrimp disease (bacterial) - Acute Hepatic pancreatic necrosis'),
#  ('Downburst', 'Oyster Disease Aquaculture'),
#  ('Downburst', 'Radioactive Waste'),
#  ('Downburst', 'Radioactive Material'),
#  ('Downburst', 'Radiation Agents'),
#  ('Downburst', 'Nuclear Agents'),
#  ('Downburst', 'Building Collapse'),
#  ('Downburst', 'Building, highrise, cladding'),
#  ('Downburst', 'Structural Failure'),
#  ('Downburst', 'Bridge Failure'),
#  ('Downburst', 'Dam Failure'),
#  ('Downburst', 'Supply Chain Failure'),
#  ('Downburst', 'Critical Infrastructure Failure'),
#  ('Downburst', 'Nuclear Plant Failure'),
#  ('Downburst', 'Power Outage/ or Blackout'),
#  ('Downburst', 'Emergency Telecommunications Failure'),
#  ('Downburst', 'Water Supply Failure'),
#  ('Downburst', 'Radio and Other Telecommunication Failures'),
#  ('Downburst', 'Misconfiguration of Software and Hardware'),
#  ('Downburst', 'Non-Conformity and Interoperability'),
#  ('Downburst', 'Malware'),
#  ('Downburst', 'Data Breach'),
#  ('Downburst', 'Data Security-Related Hazards'),
#  ('Downburst', 'Disrupt'),
#  ('Downburst', 'Outage'),
#  ('Downburst', 'Personally Identifiable Information (PII) Breach'),
#  ('Downburst', 'Internet of Things (IOT)-Related Hazards'),
#  ('Downburst', 'Cyberbullying'),
#  ('Downburst', 'Natech'),
#  ('Downburst', 'Pollution'),
#  ('Downburst', 'Explosion'),
#  ('Downburst', 'Leaks and Spills'),
#  ('Downburst', 'Soil Pollution'),
#  ('Downburst', 'Fire'),
#  ('Downburst', 'Mining Hazards'),
#  ('Downburst',
#   'Safety Hazards Associated with Oil and Gas Extraction Activities'),
#  ('Downburst', 'Disaster Waste'),
#  ('Downburst', 'Solid Waste'),
#  ('Downburst', 'Wastewater'),
#  ('Downburst', 'Hazardous Waste'),
#  ('Downburst', 'Plastic Waste'),
#  ('Downburst', 'Marine Debris'),
#  ('Downburst', 'Electronic Waste (E-Waste)'),
#  ('Downburst', 'Healthcare Risk Waste'),
#  ('Downburst', 'Landfilling'),
#  ('Downburst', 'Tailings'),
#  ('Downburst', 'Waste Treatment Lagoons'),
#  ('Downburst', 'Drain and Sewer Flooding'),
#  ('Downburst', 'Reservoir Flooding'),
#  ('Downburst', 'Air Transportation Accident'),
#  ('Downburst', 'Inland Water Ways'),
#  ('Downburst', 'Marine Accident'),
#  ('Downburst', 'Rail Accident'),
#  ('Downburst', 'Road Traffic Accident'),
#  ('Downburst', 'Explosive agents'),
#  ('Downburst', 'International Armed Conflict (IAC)'),
#  ('Downburst', 'Non-International Armed Conflict (NIAC)'),
#  ('Downburst', 'Civil Unrest'),
#  ('Downburst', 'Explosive Remnants of War'),
#  ('Downburst', 'Environmental Degradation from Conflict'),
#  ('Downburst', 'Violence'),
#  ('Downburst', 'Stampede or Crushing (Human)'),
#  ('Downburst', 'Financial shock'),
#  ('Lightning (Electrical Storm)', 'Downburst'),
#  ('Lightning (Electrical Storm)', 'Thunderstorm'),
#  ('Lightning (Electrical Storm)', 'Coastal Flood'),
#  ('Lightning (Electrical Storm)', 'Estuarine (Coastal) Flood'),
#  ('Lightning (Electrical Storm)', 'Flash Flood'),
#  ('Lightning (Electrical Storm)', 'Fluvial (Riverine) Flood'),
#  ('Lightning (Electrical Storm)', 'Groundwater Flood'),
#  ('Lightning (Electrical Storm)', 'Ice-Jam Flood Including Debris'),
#  ('Lightning (Electrical Storm)', 'Ponding (Drainage) Flood'),
#  ('Lightning (Electrical Storm)', 'Snowmelt Flood'),
#  ('Lightning (Electrical Storm)', 'Surface Water Flooding'),
#  ('Lightning (Electrical Storm)', 'Glacial Lake Outburst Flood'),
#  ('Lightning (Electrical Storm)', 'Black Carbon (Brown Clouds)'),
#  ('Lightning (Electrical Storm)', 'Dust storm or Sandstorm'),
#  ('Lightning (Electrical Storm)', 'Fog'),
#  ('Lightning (Electrical Storm)', 'Haze'),
#  ('Lightning (Electrical Storm)', 'Polluted Air'),
#  ('Lightning (Electrical Storm)', 'Sand haze'),
#  ('Lightning (Electrical Storm)', 'Smoke'),
#  ('Lightning (Electrical Storm)', 'Ocean Acidification'),
#  ('Lightning (Electrical Storm)', 'Rogue Wave'),
#  ('Lightning (Electrical Storm)', 'Sea Water Intrusion'),
#  ('Lightning (Electrical Storm)', 'Sea Ice (Ice Bergs)'),
#  ('Lightning (Electrical Storm)', 'Ice Flow'),
#  ('Lightning (Electrical Storm)', 'Seiche'),
#  ('Lightning (Electrical Storm)', 'Storm Surge'),
#  ('Lightning (Electrical Storm)', 'Storm Tides'),
#  ('Lightning (Electrical Storm)', 'Tsunami'),
#  ('Lightning (Electrical Storm)', 'Depression or Cyclone (Low Pressure Area)'),
#  ('Lightning (Electrical Storm)', 'Extra-tropical Cyclone'),
#  ('Lightning (Electrical Storm)', 'Sub-Tropical Cyclone'),
#  ('Lightning (Electrical Storm)', 'Acid Rain'),
#  ('Lightning (Electrical Storm)', 'Blizzard'),
#  ('Lightning (Electrical Storm)', 'Drought'),
#  ('Lightning (Electrical Storm)', 'Hail'),
#  ('Lightning (Electrical Storm)', 'Ice Storm'),
#  ('Lightning (Electrical Storm)', 'Snow'),
#  ('Lightning (Electrical Storm)', 'Snow Storm'),
#  ('Lightning (Electrical Storm)', 'Cold Wave'),
#  ('Lightning (Electrical Storm)', 'Dzud'),
#  ('Lightning (Electrical Storm)', 'Freeze'),
#  ('Lightning (Electrical Storm)', 'Frost (Hoar Frost)'),
#  ('Lightning (Electrical Storm)', 'Freezing Rain (Supercooled Rain)'),
#  ('Lightning (Electrical Storm)', 'Glaze'),
#  ('Lightning (Electrical Storm)', 'Ground Frost'),
#  ('Lightning (Electrical Storm)', 'Heatwave'),
#  ('Lightning (Electrical Storm)', 'Icing (Including Ice)'),
#  ('Lightning (Electrical Storm)', 'Thaw'),
#  ('Lightning (Electrical Storm)', 'Avalanche'),
#  ('Lightning (Electrical Storm)', 'Mud Flow'),
#  ('Lightning (Electrical Storm)', 'Rock slide'),
#  ('Lightning (Electrical Storm)', 'Derecho'),
#  ('Lightning (Electrical Storm)', 'Gale (Strong Gale)'),
#  ('Lightning (Electrical Storm)', 'Squall'),
#  ('Lightning (Electrical Storm)', 'Subtropical Storm'),
#  ('Lightning (Electrical Storm)',
#   'Tropical Cyclone (Cyclonic Wind/ Rain Storm Surge)'),
#  ('Lightning (Electrical Storm)', 'Tropical Storm'),
#  ('Lightning (Electrical Storm)', 'Tornado'),
#  ('Lightning (Electrical Storm)', 'Wind'),
#  ('Lightning (Electrical Storm)', 'Airburst'),
#  ('Lightning (Electrical Storm)',
#   'Geomagnetic Storm (including energetic particles related to space weather, and solar flare radio blackout [R Scale])'),
#  ('Lightning (Electrical Storm)', 'UV Radiation'),
#  ('Lightning (Electrical Storm)', 'Meteorite Impact'),
#  ('Lightning (Electrical Storm)', 'Ionospheric Storms'),
#  ('Lightning (Electrical Storm)', 'Radio Blackout'),
#  ('Lightning (Electrical Storm)',
#   'Solar Storm (Solar Radiation Storm) (S Scale)'),
#  ('Lightning (Electrical Storm)', 'Space Hazard / Accident'),
#  ('Lightning (Electrical Storm)', 'Near-Earth Object'),
#  ('Lightning (Electrical Storm)', 'Earthquake'),
#  ('Lightning (Electrical Storm)', 'Ground Shaking (Earthquake)'),
#  ('Lightning (Electrical Storm)', 'Liquefaction (Earthquake Trigger)'),
#  ('Lightning (Electrical Storm)',
#   'Earthquake Surface Rupture, Fissures, and Tectonic Uplift/Subsidence'),
#  ('Lightning (Electrical Storm)',
#   'Subsidance and Uplift, Including Shoreline Change (Earthquake Trigger)'),
#  ('Lightning (Electrical Storm)', 'Tsunami (Earthquake Trigger)'),
#  ('Lightning (Electrical Storm)',
#   'Landslide or Debris Flow (Earthquake trigger)'),
#  ('Lightning (Electrical Storm)', 'Ground Gases (Seismogenic)'),
#  ('Lightning (Electrical Storm)', 'Lava Flows (Lava Domes)'),
#  ('Lightning (Electrical Storm)', 'Ash/Tephra Fall (Physical and Chemical)'),
#  ('Lightning (Electrical Storm)', 'Ballistics (Volcanic)'),
#  ('Lightning (Electrical Storm)', 'Pyroclastic Density Current'),
#  ('Lightning (Electrical Storm)', 'Debris Flow/Lahars/Floods'),
#  ('Lightning (Electrical Storm)', 'Landslide (Volcanic Trigger)'),
#  ('Lightning (Electrical Storm)', 'Ground Shaking (Volcanic Earthquake)'),
#  ('Lightning (Electrical Storm)', 'Volcanic Gases and Aerosols'),
#  ('Lightning (Electrical Storm)', 'Tsunami (Volcanic Trigger)'),
#  ('Lightning (Electrical Storm)', 'Lightning (Volcanic Trigger)'),
#  ('Lightning (Electrical Storm)',
#   'Urban Fire (During/Following Volcanic Eruption)'),
#  ('Lightning (Electrical Storm)',
#   'Subsidence and Uplift, Including Shoreline Change (Magmatic/Volcanic Trigger)'),
#  ('Lightning (Electrical Storm)',
#   'Ground Shaking (induced earthquake, reservoir fill, dams, cavity collapse, underground explosion, impact, hydrocarbon fields, shale exploration, etc.)'),
#  ('Lightning (Electrical Storm)', 'Liquefaction (Groundwater Trigger)'),
#  ('Lightning (Electrical Storm)', 'Ground Fissuring'),
#  ('Lightning (Electrical Storm)',
#   'Subsidence and Uplift Including Shoreline Change'),
#  ('Lightning (Electrical Storm)', 'Shrink-Swell Subsidence'),
#  ('Lightning (Electrical Storm)', 'Sinkhole'),
#  ('Lightning (Electrical Storm)', 'Ground Gases (CH4, Rn, etc.)'),
#  ('Lightning (Electrical Storm)', 'Riverbank Erosion'),
#  ('Lightning (Electrical Storm)', 'Sand Encroachment'),
#  ('Lightning (Electrical Storm)',
#   'Aquifer Recharge (Systems Failure/ Outages)'),
#  ('Lightning (Electrical Storm)', 'Submarine Landslide'),
#  ('Lightning (Electrical Storm)', 'Rockfall'),
#  ('Lightning (Electrical Storm)', 'Landscape Creep'),
#  ('Lightning (Electrical Storm)', 'Sediment Rock Avalanche'),
#  ('Lightning (Electrical Storm)', 'Tsunami (Submarine Landslide Trigger)'),
#  ('Lightning (Electrical Storm)', 'Household Air Pollution'),
#  ('Lightning (Electrical Storm)', 'Air Pollution (Point Source)'),
#  ('Lightning (Electrical Storm)', 'Ambient (Outdoor) Air Pollution'),
#  ('Lightning (Electrical Storm)', 'Land Degradation'),
#  ('Lightning (Electrical Storm)', 'Soil Degradation'),
#  ('Lightning (Electrical Storm)', 'Runoff / Nonpoint Source Pollution'),
#  ('Lightning (Electrical Storm)', 'Salinity'),
#  ('Lightning (Electrical Storm)', 'Biodiversity Loss'),
#  ('Lightning (Electrical Storm)', 'Deforestation'),
#  ('Lightning (Electrical Storm)', 'Forest Declines and Diebacks'),
#  ('Lightning (Electrical Storm)', 'Forest Disturbances'),
#  ('Lightning (Electrical Storm)', 'Forest Invasive Species'),
#  ('Lightning (Electrical Storm)', 'Wildfires'),
#  ('Lightning (Electrical Storm)', 'Desertification'),
#  ('Lightning (Electrical Storm)', 'Loss of Mangroves'),
#  ('Lightning (Electrical Storm)', 'Wetland Loss/Degradation'),
#  ('Lightning (Electrical Storm)', 'Coral Bleaching'),
#  ('Lightning (Electrical Storm)', 'Compressive Soils'),
#  ('Lightning (Electrical Storm)', 'Soil Erosion'),
#  ('Lightning (Electrical Storm)', 'Coastal Erosion and Shoreline Change'),
#  ('Lightning (Electrical Storm)', 'Permafrost Loss'),
#  ('Lightning (Electrical Storm)', 'Sand Mining'),
#  ('Lightning (Electrical Storm)', 'Sea Level Rise'),
#  ('Lightning (Electrical Storm)', 'Eutrophication'),
#  ('Lightning (Electrical Storm)', 'Ammonia'),
#  ('Lightning (Electrical Storm)', 'Carbon Monoxide'),
#  ('Lightning (Electrical Storm)', 'Arsenic'),
#  ('Lightning (Electrical Storm)', 'Cadmium'),
#  ('Lightning (Electrical Storm)', 'Lead'),
#  ('Lightning (Electrical Storm)', 'Mercury'),
#  ('Lightning (Electrical Storm)', 'Levels of Contaminants in Food and Feed'),
#  ('Lightning (Electrical Storm)', 'Pesticides – Highly Hazardous'),
#  ('Lightning (Electrical Storm)', 'Residue of Pesticides'),
#  ('Lightning (Electrical Storm)',
#   'Hazardous Pesticide Contamination in Soils'),
#  ('Lightning (Electrical Storm)', 'Insecticides'),
#  ('Lightning (Electrical Storm)', 'Fungicides'),
#  ('Lightning (Electrical Storm)', 'Dioxins and Dioxin-like Substances'),
#  ('Lightning (Electrical Storm)', 'Microplastics'),
#  ('Lightning (Electrical Storm)', 'Phosphine'),
#  ('Lightning (Electrical Storm)', 'Chlorine'),
#  ('Lightning (Electrical Storm)', 'Oil Pollution'),
#  ('Lightning (Electrical Storm)', 'Benzene'),
#  ('Lightning (Electrical Storm)', 'Chemical Warfare Agents'),
#  ('Lightning (Electrical Storm)', 'Asbestos'),
#  ('Lightning (Electrical Storm)', 'Aflatoxins'),
#  ('Lightning (Electrical Storm)', 'Fluoride - Excess or inadequate intake'),
#  ('Lightning (Electrical Storm)', 'Methanol'),
#  ('Lightning (Electrical Storm)',
#   'Substandard and Falsified Medical Products'),
#  ('Lightning (Electrical Storm)', 'Marine Toxins'),
#  ('Lightning (Electrical Storm)', 'Harmful Algal Blooms'),
#  ('Lightning (Electrical Storm)', 'Insect Pest Infestations'),
#  ('Lightning (Electrical Storm)', 'Locust'),
#  ('Lightning (Electrical Storm)', 'Invasive Weeds'),
#  ('Lightning (Electrical Storm)', 'Invasive Species'),
#  ('Lightning (Electrical Storm)', 'Snake Envenomation'),
#  ('Lightning (Electrical Storm)', 'Human-Wildlife Conflict'),
#  ('Lightning (Electrical Storm)', 'Biological Agents'),
#  ('Lightning (Electrical Storm)', 'Suicide Cluster'),
#  ('Lightning (Electrical Storm)', 'Antimicrobial Resistance'),
#  ('Lightning (Electrical Storm)',
#   'Foodborne Microbial Hazards (including human enteric virus and foodborne parasite)'),
#  ('Lightning (Electrical Storm)', 'Bacterial Plant Disease'),
#  ('Lightning (Electrical Storm)', 'Fungal Plant Disease'),
#  ('Lightning (Electrical Storm)',
#   'Viral, Mycoplasma and Viroid Plant Disease Epidemics'),
#  ('Lightning (Electrical Storm)', 'Anthrax'),
#  ('Lightning (Electrical Storm)', 'Airborne Diseases'),
#  ('Lightning (Electrical Storm)', 'Blood Borne Viruses'),
#  ('Lightning (Electrical Storm)', 'Waterborne Diseases'),
#  ('Lightning (Electrical Storm)', 'Foodborne Diseases'),
#  ('Lightning (Electrical Storm)', 'Sexually Transmitted Diseases (Human)'),
#  ('Lightning (Electrical Storm)', 'Neglected Tropical Diseases (Human)'),
#  ('Lightning (Electrical Storm)', 'Vaccine-Preventable Diseases (Human)'),
#  ('Lightning (Electrical Storm)', 'Vector Borne Diseases (VBD) (Human)'),
#  ('Lightning (Electrical Storm)', 'Viral Haemorrhagic Fevers (Human)'),
#  ('Lightning (Electrical Storm)',
#   'Antimicrobial Resistant Microorganisms (Human)'),
#  ('Lightning (Electrical Storm)', 'Animal Diseases (Not Zoonoses)'),
#  ('Lightning (Electrical Storm)', 'Zoonotic Diseases'),
#  ('Lightning (Electrical Storm)', 'Diarrhoeal Diseases (Human)'),
#  ('Lightning (Electrical Storm)', 'Prion Diseases'),
#  ('Lightning (Electrical Storm)', 'Hepatitis B (Human)'),
#  ('Lightning (Electrical Storm)', 'Hepatitis C (human)'),
#  ('Lightning (Electrical Storm)', 'HIV and AIDS (Human)'),
#  ('Lightning (Electrical Storm)', 'COVID-19 (SARS-CoV-2) (Human)'),
#  ('Lightning (Electrical Storm)', 'Cholera (Human)'),
#  ('Lightning (Electrical Storm)', 'Cryptosporidium (Human)'),
#  ('Lightning (Electrical Storm)', 'Paratyphoid fever (Human)'),
#  ('Lightning (Electrical Storm)', 'Typhoid Fever (Human)'),
#  ('Lightning (Electrical Storm)', 'Hepatitis A (Human)'),
#  ('Lightning (Electrical Storm)', 'Escherichia Coli (STEC) (Human)'),
#  ('Lightning (Electrical Storm)', 'Listeriosis (Human)'),
#  ('Lightning (Electrical Storm)', 'Shigellosis (Human)'),
#  ('Lightning (Electrical Storm)', 'Avian Influenza (Human and Animal)'),
#  ('Lightning (Electrical Storm)', 'Pandemic Influenza (Human)'),
#  ('Lightning (Electrical Storm)', 'Seasonal Influenza (Human)'),
#  ('Lightning (Electrical Storm)', 'Cysticercosis'),
#  ('Lightning (Electrical Storm)', 'Leptospirosis (Human)'),
#  ('Lightning (Electrical Storm)', 'Plague (Human)'),
#  ('Lightning (Electrical Storm)', 'Leprosy'),
#  ('Lightning (Electrical Storm)', 'Chikungunya'),
#  ('Lightning (Electrical Storm)', 'Zika Virus (human)'),
#  ('Lightning (Electrical Storm)', 'Diphtheria (Human)'),
#  ('Lightning (Electrical Storm)', 'Measles (Human)'),
#  ('Lightning (Electrical Storm)', 'Meningococcal Meningitis (Human)'),
#  ('Lightning (Electrical Storm)', 'Pertussis (Human)'),
#  ('Lightning (Electrical Storm)', 'Polio (Human)'),
#  ('Lightning (Electrical Storm)', 'Smallpox (Human)'),
#  ('Lightning (Electrical Storm)', 'Varicella and herpes zoster (Human)'),
#  ('Lightning (Electrical Storm)', 'Yellow Fever (Human)'),
#  ('Lightning (Electrical Storm)', 'Dengue (Human)'),
#  ('Lightning (Electrical Storm)', 'Malaria (Human)'),
#  ('Lightning (Electrical Storm)', 'Crimean-Congo Haemorrhagic Fever (Human)'),
#  ('Lightning (Electrical Storm)', 'Ebola (Human)'),
#  ('Lightning (Electrical Storm)', 'Lassa Fever (Human)'),
#  ('Lightning (Electrical Storm)', 'Tuberculosis (Human and Animal)'),
#  ('Lightning (Electrical Storm)',
#   'Middle East Respiratory Syndrome (MERS) (Human)'),
#  ('Lightning (Electrical Storm)', 'Monkeypox (Human)'),
#  ('Lightning (Electrical Storm)', 'Rabies (Animal and Human)'),
#  ('Lightning (Electrical Storm)',
#   'Severe Acute Respiratory Syndrome (SARS) (Human)'),
#  ('Lightning (Electrical Storm)', 'Rotavirus (Human)'),
#  ('Lightning (Electrical Storm)', 'African Swine Fever (Animal)'),
#  ('Lightning (Electrical Storm)', 'Vector-borne diseases (VBD) (Animals)'),
#  ('Lightning (Electrical Storm)', 'Brucellosis (Animal)'),
#  ('Lightning (Electrical Storm)', 'Classical Swine Fever (Animal)'),
#  ('Lightning (Electrical Storm)',
#   'Contagious Bovine Pleuropneumonia (CBPP) (Animal)'),
#  ('Lightning (Electrical Storm)',
#   'Contagious Caprine Pleuropneumonia (CCPP) (Animal)'),
#  ('Lightning (Electrical Storm)', 'Foot and Mouth Disease Virus (Animal)'),
#  ('Lightning (Electrical Storm)', 'Lumpy Skin Disease (Animal)'),
#  ('Lightning (Electrical Storm)', 'New World Screwworm (NWS) (Animal)'),
#  ('Lightning (Electrical Storm)', 'Newcastle Disease Virus (Animal)'),
#  ('Lightning (Electrical Storm)', 'Peste Des Petits Ruminants (Animal)'),
#  ('Lightning (Electrical Storm)', 'Q Fever'),
#  ('Lightning (Electrical Storm)', 'Rift Valley Fever (Animal)'),
#  ('Lightning (Electrical Storm)', 'Trypanosomosis (Animal)'),
#  ('Lightning (Electrical Storm)', 'West Nile Fever (Human)'),
#  ('Lightning (Electrical Storm)', 'Rinderpest (Animal)'),
#  ('Lightning (Electrical Storm)', 'Trypanosomiasis (Human)'),
#  ('Lightning (Electrical Storm)',
#   'Shrimp disease (bacterial) - Acute Hepatic pancreatic necrosis'),
#  ('Lightning (Electrical Storm)', 'Oyster Disease Aquaculture'),
#  ('Lightning (Electrical Storm)', 'Radioactive Waste'),
#  ('Lightning (Electrical Storm)', 'Radioactive Material'),
#  ('Lightning (Electrical Storm)', 'Radiation Agents'),
#  ('Lightning (Electrical Storm)', 'Nuclear Agents'),
#  ('Lightning (Electrical Storm)', 'Building Collapse'),
#  ('Lightning (Electrical Storm)', 'Building, highrise, cladding'),
#  ('Lightning (Electrical Storm)', 'Structural Failure'),
#  ('Lightning (Electrical Storm)', 'Bridge Failure'),
#  ('Lightning (Electrical Storm)', 'Dam Failure'),
#  ('Lightning (Electrical Storm)', 'Supply Chain Failure'),
#  ('Lightning (Electrical Storm)', 'Critical Infrastructure Failure'),
#  ('Lightning (Electrical Storm)', 'Nuclear Plant Failure'),
#  ('Lightning (Electrical Storm)', 'Power Outage/ or Blackout'),
#  ('Lightning (Electrical Storm)', 'Emergency Telecommunications Failure'),
#  ('Lightning (Electrical Storm)', 'Water Supply Failure'),
#  ('Lightning (Electrical Storm)',
#   'Radio and Other Telecommunication Failures'),
#  ('Lightning (Electrical Storm)', 'Misconfiguration of Software and Hardware'),
#  ('Lightning (Electrical Storm)', 'Non-Conformity and Interoperability'),
#  ('Lightning (Electrical Storm)', 'Malware'),
#  ('Lightning (Electrical Storm)', 'Data Breach'),
#  ('Lightning (Electrical Storm)', 'Data Security-Related Hazards'),
#  ('Lightning (Electrical Storm)', 'Disrupt'),
#  ('Lightning (Electrical Storm)', 'Outage'),
#  ('Lightning (Electrical Storm)',
#   'Personally Identifiable Information (PII) Breach'),
#  ('Lightning (Electrical Storm)', 'Internet of Things (IOT)-Related Hazards'),
#  ('Lightning (Electrical Storm)', 'Cyberbullying'),
#  ('Lightning (Electrical Storm)', 'Natech'),
#  ('Lightning (Electrical Storm)', 'Pollution'),
#  ('Lightning (Electrical Storm)', 'Explosion'),
#  ('Lightning (Electrical Storm)', 'Leaks and Spills'),
#  ('Lightning (Electrical Storm)', 'Soil Pollution'),
#  ('Lightning (Electrical Storm)', 'Fire'),
#  ('Lightning (Electrical Storm)', 'Mining Hazards'),
#  ('Lightning (Electrical Storm)',
#   'Safety Hazards Associated with Oil and Gas Extraction Activities'),
#  ('Lightning (Electrical Storm)', 'Disaster Waste'),
#  ('Lightning (Electrical Storm)', 'Solid Waste'),
#  ('Lightning (Electrical Storm)', 'Wastewater'),
#  ('Lightning (Electrical Storm)', 'Hazardous Waste'),
#  ('Lightning (Electrical Storm)', 'Plastic Waste'),
#  ('Lightning (Electrical Storm)', 'Marine Debris'),
#  ('Lightning (Electrical Storm)', 'Electronic Waste (E-Waste)'),
#  ('Lightning (Electrical Storm)', 'Healthcare Risk Waste'),
#  ('Lightning (Electrical Storm)', 'Landfilling'),
#  ('Lightning (Electrical Storm)', 'Tailings'),
#  ('Lightning (Electrical Storm)', 'Waste Treatment Lagoons'),
#  ('Lightning (Electrical Storm)', 'Drain and Sewer Flooding'),
#  ('Lightning (Electrical Storm)', 'Reservoir Flooding'),
#  ('Lightning (Electrical Storm)', 'Air Transportation Accident'),
#  ('Lightning (Electrical Storm)', 'Inland Water Ways'),
#  ('Lightning (Electrical Storm)', 'Marine Accident'),
#  ('Lightning (Electrical Storm)', 'Rail Accident'),
#  ('Lightning (Electrical Storm)', 'Road Traffic Accident'),
#  ('Lightning (Electrical Storm)', 'Explosive agents'),
#  ('Lightning (Electrical Storm)', 'International Armed Conflict (IAC)'),
#  ('Lightning (Electrical Storm)', 'Non-International Armed Conflict (NIAC)'),
#  ('Lightning (Electrical Storm)', 'Civil Unrest'),
#  ('Lightning (Electrical Storm)', 'Explosive Remnants of War'),
#  ('Lightning (Electrical Storm)', 'Environmental Degradation from Conflict'),
#  ('Lightning (Electrical Storm)', 'Violence'),
#  ('Lightning (Electrical Storm)', 'Stampede or Crushing (Human)'),
#  ('Lightning (Electrical Storm)', 'Financial shock'),
#  ('Thunderstorm', 'Downburst'),
#  ('Thunderstorm', 'Lightning (Electrical Storm)'),
#  ('Thunderstorm', 'Coastal Flood'),
#  ('Thunderstorm', 'Estuarine (Coastal) Flood'),
#  ('Thunderstorm', 'Flash Flood'),
#  ('Thunderstorm', 'Fluvial (Riverine) Flood'),
#  ('Thunderstorm', 'Groundwater Flood'),
#  ('Thunderstorm', 'Ice-Jam Flood Including Debris'),
#  ('Thunderstorm', 'Ponding (Drainage) Flood'),
#  ('Thunderstorm', 'Snowmelt Flood'),
#  ('Thunderstorm', 'Surface Water Flooding'),
#  ('Thunderstorm', 'Glacial Lake Outburst Flood'),
#  ('Thunderstorm', 'Black Carbon (Brown Clouds)'),
#  ('Thunderstorm', 'Dust storm or Sandstorm'),
#  ('Thunderstorm', 'Fog'),
#  ('Thunderstorm', 'Haze'),
#  ('Thunderstorm', 'Polluted Air'),
#  ('Thunderstorm', 'Sand haze'),
#  ('Thunderstorm', 'Smoke'),
#  ('Thunderstorm', 'Ocean Acidification'),
#  ('Thunderstorm', 'Rogue Wave'),
#  ('Thunderstorm', 'Sea Water Intrusion'),
#  ('Thunderstorm', 'Sea Ice (Ice Bergs)'),
#  ('Thunderstorm', 'Ice Flow'),
#  ('Thunderstorm', 'Seiche'),
#  ('Thunderstorm', 'Storm Surge'),
#  ('Thunderstorm', 'Storm Tides'),
#  ('Thunderstorm', 'Tsunami'),
#  ('Thunderstorm', 'Depression or Cyclone (Low Pressure Area)'),
#  ('Thunderstorm', 'Extra-tropical Cyclone'),
#  ('Thunderstorm', 'Sub-Tropical Cyclone'),
#  ('Thunderstorm', 'Acid Rain'),
#  ('Thunderstorm', 'Blizzard'),
#  ('Thunderstorm', 'Drought'),
#  ('Thunderstorm', 'Hail'),
#  ('Thunderstorm', 'Ice Storm'),
#  ('Thunderstorm', 'Snow'),
#  ('Thunderstorm', 'Snow Storm'),
#  ('Thunderstorm', 'Cold Wave'),
#  ('Thunderstorm', 'Dzud'),
#  ('Thunderstorm', 'Freeze'),
#  ('Thunderstorm', 'Frost (Hoar Frost)'),
#  ('Thunderstorm', 'Freezing Rain (Supercooled Rain)'),
#  ('Thunderstorm', 'Glaze'),
#  ('Thunderstorm', 'Ground Frost'),
#  ('Thunderstorm', 'Heatwave'),
#  ('Thunderstorm', 'Icing (Including Ice)'),
#  ('Thunderstorm', 'Thaw'),
#  ('Thunderstorm', 'Avalanche'),
#  ('Thunderstorm', 'Mud Flow'),
#  ('Thunderstorm', 'Rock slide'),
#  ('Thunderstorm', 'Derecho'),
#  ('Thunderstorm', 'Gale (Strong Gale)'),
#  ('Thunderstorm', 'Squall'),
#  ('Thunderstorm', 'Subtropical Storm'),
#  ('Thunderstorm', 'Tropical Cyclone (Cyclonic Wind/ Rain Storm Surge)'),
#  ('Thunderstorm', 'Tropical Storm'),
#  ('Thunderstorm', 'Tornado'),
#  ('Thunderstorm', 'Wind'),
#  ('Thunderstorm', 'Airburst'),
#  ('Thunderstorm',
#   'Geomagnetic Storm (including energetic particles related to space weather, and solar flare radio blackout [R Scale])'),
#  ('Thunderstorm', 'UV Radiation'),
#  ('Thunderstorm', 'Meteorite Impact'),
#  ('Thunderstorm', 'Ionospheric Storms'),
#  ('Thunderstorm', 'Radio Blackout'),
#  ('Thunderstorm', 'Solar Storm (Solar Radiation Storm) (S Scale)'),
#  ('Thunderstorm', 'Space Hazard / Accident'),
#  ('Thunderstorm', 'Near-Earth Object'),
#  ('Thunderstorm', 'Earthquake'),
#  ('Thunderstorm', 'Ground Shaking (Earthquake)'),
#  ('Thunderstorm', 'Liquefaction (Earthquake Trigger)'),
#  ('Thunderstorm',
#   'Earthquake Surface Rupture, Fissures, and Tectonic Uplift/Subsidence'),
#  ('Thunderstorm',
#   'Subsidance and Uplift, Including Shoreline Change (Earthquake Trigger)'),
#  ('Thunderstorm', 'Tsunami (Earthquake Trigger)'),
#  ('Thunderstorm', 'Landslide or Debris Flow (Earthquake trigger)'),
#  ('Thunderstorm', 'Ground Gases (Seismogenic)'),
#  ('Thunderstorm', 'Lava Flows (Lava Domes)'),
#  ('Thunderstorm', 'Ash/Tephra Fall (Physical and Chemical)'),
#  ('Thunderstorm', 'Ballistics (Volcanic)'),
#  ('Thunderstorm', 'Pyroclastic Density Current'),
#  ('Thunderstorm', 'Debris Flow/Lahars/Floods'),
#  ('Thunderstorm', 'Landslide (Volcanic Trigger)'),
#  ('Thunderstorm', 'Ground Shaking (Volcanic Earthquake)'),
#  ('Thunderstorm', 'Volcanic Gases and Aerosols'),
#  ('Thunderstorm', 'Tsunami (Volcanic Trigger)'),
#  ('Thunderstorm', 'Lightning (Volcanic Trigger)'),
#  ('Thunderstorm', 'Urban Fire (During/Following Volcanic Eruption)'),
#  ('Thunderstorm',
#   'Subsidence and Uplift, Including Shoreline Change (Magmatic/Volcanic Trigger)'),
#  ('Thunderstorm',
#   'Ground Shaking (induced earthquake, reservoir fill, dams, cavity collapse, underground explosion, impact, hydrocarbon fields, shale exploration, etc.)'),
#  ('Thunderstorm', 'Liquefaction (Groundwater Trigger)'),
#  ('Thunderstorm', 'Ground Fissuring'),
#  ('Thunderstorm', 'Subsidence and Uplift Including Shoreline Change'),
#  ('Thunderstorm', 'Shrink-Swell Subsidence'),
#  ('Thunderstorm', 'Sinkhole'),
#  ('Thunderstorm', 'Ground Gases (CH4, Rn, etc.)'),
#  ('Thunderstorm', 'Riverbank Erosion'),
#  ('Thunderstorm', 'Sand Encroachment'),
#  ('Thunderstorm', 'Aquifer Recharge (Systems Failure/ Outages)'),
#  ('Thunderstorm', 'Submarine Landslide'),
#  ('Thunderstorm', 'Rockfall'),
#  ('Thunderstorm', 'Landscape Creep'),
#  ('Thunderstorm', 'Sediment Rock Avalanche'),
#  ('Thunderstorm', 'Tsunami (Submarine Landslide Trigger)'),
#  ('Thunderstorm', 'Household Air Pollution'),
#  ('Thunderstorm', 'Air Pollution (Point Source)'),
#  ('Thunderstorm', 'Ambient (Outdoor) Air Pollution'),
#  ('Thunderstorm', 'Land Degradation'),
#  ('Thunderstorm', 'Soil Degradation'),
#  ('Thunderstorm', 'Runoff / Nonpoint Source Pollution'),
#  ('Thunderstorm', 'Salinity'),
#  ('Thunderstorm', 'Biodiversity Loss'),
#  ('Thunderstorm', 'Deforestation'),
#  ('Thunderstorm', 'Forest Declines and Diebacks'),
#  ('Thunderstorm', 'Forest Disturbances'),
#  ('Thunderstorm', 'Forest Invasive Species'),
#  ('Thunderstorm', 'Wildfires'),
#  ('Thunderstorm', 'Desertification'),
#  ('Thunderstorm', 'Loss of Mangroves'),
#  ('Thunderstorm', 'Wetland Loss/Degradation'),
#  ('Thunderstorm', 'Coral Bleaching'),
#  ('Thunderstorm', 'Compressive Soils'),
#  ('Thunderstorm', 'Soil Erosion'),
#  ('Thunderstorm', 'Coastal Erosion and Shoreline Change'),
#  ('Thunderstorm', 'Permafrost Loss'),
#  ('Thunderstorm', 'Sand Mining'),
#  ('Thunderstorm', 'Sea Level Rise'),
#  ('Thunderstorm', 'Eutrophication'),
#  ('Thunderstorm', 'Ammonia'),
#  ('Thunderstorm', 'Carbon Monoxide'),
#  ('Thunderstorm', 'Arsenic'),
#  ('Thunderstorm', 'Cadmium'),
#  ('Thunderstorm', 'Lead'),
#  ('Thunderstorm', 'Mercury'),
#  ('Thunderstorm', 'Levels of Contaminants in Food and Feed'),
#  ('Thunderstorm', 'Pesticides – Highly Hazardous'),
#  ('Thunderstorm', 'Residue of Pesticides'),
#  ('Thunderstorm', 'Hazardous Pesticide Contamination in Soils'),
#  ('Thunderstorm', 'Insecticides'),
#  ('Thunderstorm', 'Fungicides'),
#  ('Thunderstorm', 'Dioxins and Dioxin-like Substances'),
#  ('Thunderstorm', 'Microplastics'),
#  ('Thunderstorm', 'Phosphine'),
#  ('Thunderstorm', 'Chlorine'),
#  ('Thunderstorm', 'Oil Pollution'),
#  ('Thunderstorm', 'Benzene'),
#  ('Thunderstorm', 'Chemical Warfare Agents'),
#  ('Thunderstorm', 'Asbestos'),
#  ('Thunderstorm', 'Aflatoxins'),
#  ('Thunderstorm', 'Fluoride - Excess or inadequate intake'),
#  ('Thunderstorm', 'Methanol'),
#  ('Thunderstorm', 'Substandard and Falsified Medical Products'),
#  ('Thunderstorm', 'Marine Toxins'),
#  ('Thunderstorm', 'Harmful Algal Blooms'),
#  ('Thunderstorm', 'Insect Pest Infestations'),
#  ('Thunderstorm', 'Locust'),
#  ('Thunderstorm', 'Invasive Weeds'),
#  ('Thunderstorm', 'Invasive Species'),
#  ('Thunderstorm', 'Snake Envenomation'),
#  ('Thunderstorm', 'Human-Wildlife Conflict'),
#  ('Thunderstorm', 'Biological Agents'),
#  ('Thunderstorm', 'Suicide Cluster'),
#  ('Thunderstorm', 'Antimicrobial Resistance'),
#  ('Thunderstorm',
#   'Foodborne Microbial Hazards (including human enteric virus and foodborne parasite)'),
#  ('Thunderstorm', 'Bacterial Plant Disease'),
#  ('Thunderstorm', 'Fungal Plant Disease'),
#  ('Thunderstorm', 'Viral, Mycoplasma and Viroid Plant Disease Epidemics'),
#  ('Thunderstorm', 'Anthrax'),
#  ('Thunderstorm', 'Airborne Diseases'),
#  ('Thunderstorm', 'Blood Borne Viruses'),
#  ('Thunderstorm', 'Waterborne Diseases'),
#  ('Thunderstorm', 'Foodborne Diseases'),
#  ('Thunderstorm', 'Sexually Transmitted Diseases (Human)'),
#  ('Thunderstorm', 'Neglected Tropical Diseases (Human)'),
#  ('Thunderstorm', 'Vaccine-Preventable Diseases (Human)'),
#  ('Thunderstorm', 'Vector Borne Diseases (VBD) (Human)'),
#  ('Thunderstorm', 'Viral Haemorrhagic Fevers (Human)'),
#  ('Thunderstorm', 'Antimicrobial Resistant Microorganisms (Human)'),
#  ('Thunderstorm', 'Animal Diseases (Not Zoonoses)'),
#  ('Thunderstorm', 'Zoonotic Diseases'),
#  ('Thunderstorm', 'Diarrhoeal Diseases (Human)'),
#  ('Thunderstorm', 'Prion Diseases'),
#  ('Thunderstorm', 'Hepatitis B (Human)'),
#  ('Thunderstorm', 'Hepatitis C (human)'),
#  ('Thunderstorm', 'HIV and AIDS (Human)'),
#  ('Thunderstorm', 'COVID-19 (SARS-CoV-2) (Human)'),
#  ('Thunderstorm', 'Cholera (Human)'),
#  ('Thunderstorm', 'Cryptosporidium (Human)'),
#  ('Thunderstorm', 'Paratyphoid fever (Human)'),
#  ('Thunderstorm', 'Typhoid Fever (Human)'),
#  ('Thunderstorm', 'Hepatitis A (Human)'),
#  ('Thunderstorm', 'Escherichia Coli (STEC) (Human)'),
#  ('Thunderstorm', 'Listeriosis (Human)'),
#  ('Thunderstorm', 'Shigellosis (Human)'),
#  ('Thunderstorm', 'Avian Influenza (Human and Animal)'),
#  ('Thunderstorm', 'Pandemic Influenza (Human)'),
#  ('Thunderstorm', 'Seasonal Influenza (Human)'),
#  ('Thunderstorm', 'Cysticercosis'),
#  ('Thunderstorm', 'Leptospirosis (Human)'),
#  ('Thunderstorm', 'Plague (Human)'),
#  ('Thunderstorm', 'Leprosy'),
#  ('Thunderstorm', 'Chikungunya'),
#  ('Thunderstorm', 'Zika Virus (human)'),
#  ('Thunderstorm', 'Diphtheria (Human)'),
#  ('Thunderstorm', 'Measles (Human)'),
#  ('Thunderstorm', 'Meningococcal Meningitis (Human)'),
#  ('Thunderstorm', 'Pertussis (Human)'),
#  ('Thunderstorm', 'Polio (Human)'),
#  ('Thunderstorm', 'Smallpox (Human)'),
#  ('Thunderstorm', 'Varicella and herpes zoster (Human)'),
#  ('Thunderstorm', 'Yellow Fever (Human)'),
#  ('Thunderstorm', 'Dengue (Human)'),
#  ('Thunderstorm', 'Malaria (Human)'),
#  ('Thunderstorm', 'Crimean-Congo Haemorrhagic Fever (Human)'),
#  ('Thunderstorm', 'Ebola (Human)'),
#  ('Thunderstorm', 'Lassa Fever (Human)'),
#  ('Thunderstorm', 'Tuberculosis (Human and Animal)'),
#  ('Thunderstorm', 'Middle East Respiratory Syndrome (MERS) (Human)'),
#  ('Thunderstorm', 'Monkeypox (Human)'),
#  ('Thunderstorm', 'Rabies (Animal and Human)'),
#  ('Thunderstorm', 'Severe Acute Respiratory Syndrome (SARS) (Human)'),
#  ('Thunderstorm', 'Rotavirus (Human)'),
#  ('Thunderstorm', 'African Swine Fever (Animal)'),
#  ('Thunderstorm', 'Vector-borne diseases (VBD) (Animals)'),
#  ('Thunderstorm', 'Brucellosis (Animal)'),
#  ('Thunderstorm', 'Classical Swine Fever (Animal)'),
#  ('Thunderstorm', 'Contagious Bovine Pleuropneumonia (CBPP) (Animal)'),
#  ('Thunderstorm', 'Contagious Caprine Pleuropneumonia (CCPP) (Animal)'),
#  ('Thunderstorm', 'Foot and Mouth Disease Virus (Animal)'),
#  ('Thunderstorm', 'Lumpy Skin Disease (Animal)'),
#  ('Thunderstorm', 'New World Screwworm (NWS) (Animal)'),
#  ('Thunderstorm', 'Newcastle Disease Virus (Animal)'),
#  ('Thunderstorm', 'Peste Des Petits Ruminants (Animal)'),
#  ('Thunderstorm', 'Q Fever'),
#  ('Thunderstorm', 'Rift Valley Fever (Animal)'),
#  ('Thunderstorm', 'Trypanosomosis (Animal)'),
#  ('Thunderstorm', 'West Nile Fever (Human)'),
#  ('Thunderstorm', 'Rinderpest (Animal)'),
#  ('Thunderstorm', 'Trypanosomiasis (Human)'),
#  ('Thunderstorm',
#   'Shrimp disease (bacterial) - Acute Hepatic pancreatic necrosis'),
#  ('Thunderstorm', 'Oyster Disease Aquaculture'),
#  ('Thunderstorm', 'Radioactive Waste'),
#  ('Thunderstorm', 'Radioactive Material'),
#  ('Thunderstorm', 'Radiation Agents'),
#  ('Thunderstorm', 'Nuclear Agents'),
#  ('Thunderstorm', 'Building Collapse'),
#  ('Thunderstorm', 'Building, highrise, cladding'),
#  ('Thunderstorm', 'Structural Failure'),
#  ('Thunderstorm', 'Bridge Failure'),
#  ('Thunderstorm', 'Dam Failure'),
#  ('Thunderstorm', 'Supply Chain Failure'),
#  ('Thunderstorm', 'Critical Infrastructure Failure'),
#  ('Thunderstorm', 'Nuclear Plant Failure'),
#  ('Thunderstorm', 'Power Outage/ or Blackout'),
#  ('Thunderstorm', 'Emergency Telecommunications Failure'),
#  ('Thunderstorm', 'Water Supply Failure'),
#  ('Thunderstorm', 'Radio and Other Telecommunication Failures'),
#  ('Thunderstorm', 'Misconfiguration of Software and Hardware'),
#  ('Thunderstorm', 'Non-Conformity and Interoperability'),
#  ('Thunderstorm', 'Malware'),
#  ('Thunderstorm', 'Data Breach'),
#  ('Thunderstorm', 'Data Security-Related Hazards'),
#  ('Thunderstorm', 'Disrupt'),
#  ('Thunderstorm', 'Outage'),
#  ('Thunderstorm', 'Personally Identifiable Information (PII) Breach'),
#  ('Thunderstorm', 'Internet of Things (IOT)-Related Hazards'),
#  ('Thunderstorm', 'Cyberbullying'),
#  ('Thunderstorm', 'Natech'),
#  ('Thunderstorm', 'Pollution'),
#  ('Thunderstorm', 'Explosion'),
#  ('Thunderstorm', 'Leaks and Spills'),
#  ('Thunderstorm', 'Soil Pollution'),
#  ('Thunderstorm', 'Fire'),
#  ('Thunderstorm', 'Mining Hazards'),
#  ('Thunderstorm',
#   'Safety Hazards Associated with Oil and Gas Extraction Activities'),
#  ('Thunderstorm', 'Disaster Waste'),
#  ('Thunderstorm', 'Solid Waste'),
#  ('Thunderstorm', 'Wastewater'),
#  ('Thunderstorm', 'Hazardous Waste'),
#  ('Thunderstorm', 'Plastic Waste'),
#  ('Thunderstorm', 'Marine Debris'),
#  ('Thunderstorm', 'Electronic Waste (E-Waste)'),
#  ('Thunderstorm', 'Healthcare Risk Waste'),
#  ('Thunderstorm', 'Landfilling'),
#  ('Thunderstorm', 'Tailings'),
#  ('Thunderstorm', 'Waste Treatment Lagoons'),
#  ('Thunderstorm', 'Drain and Sewer Flooding'),
#  ('Thunderstorm', 'Reservoir Flooding'),
#  ('Thunderstorm', 'Air Transportation Accident'),
#  ('Thunderstorm', 'Inland Water Ways'),
#  ('Thunderstorm', 'Marine Accident'),
#  ('Thunderstorm', 'Rail Accident'),
#  ('Thunderstorm', 'Road Traffic Accident'),
#  ('Thunderstorm', 'Explosive agents'),
#  ('Thunderstorm', 'International Armed Conflict (IAC)'),
#  ('Thunderstorm', 'Non-International Armed Conflict (NIAC)'),
#  ('Thunderstorm', 'Civil Unrest'),
#  ('Thunderstorm', 'Explosive Remnants of War'),
#  ('Thunderstorm', 'Environmental Degradation from Conflict'),
#  ('Thunderstorm', 'Violence'),
#  ('Thunderstorm', 'Stampede or Crushing (Human)'),
#  ('Thunderstorm', 'Financial shock'),
#  ('Coastal Flood', 'Downburst'),
#  ('Coastal Flood', 'Lightning (Electrical Storm)'),
#  ('Coastal Flood', 'Thunderstorm'),
#  ('Coastal Flood', 'Estuarine (Coastal) Flood'),
#  ('Coastal Flood', 'Flash Flood'),
#  ('Coastal Flood', 'Fluvial (Riverine) Flood'),
#  ('Coastal Flood', 'Groundwater Flood'),
#  ('Coastal Flood', 'Ice-Jam Flood Including Debris'),
#  ('Coastal Flood', 'Ponding (Drainage) Flood'),
#  ('Coastal Flood', 'Snowmelt Flood'),
#  ('Coastal Flood', 'Surface Water Flooding'),
#  ('Coastal Flood', 'Glacial Lake Outburst Flood'),
#  ('Coastal Flood', 'Black Carbon (Brown Clouds)'),
#  ('Coastal Flood', 'Dust storm or Sandstorm'),
#  ('Coastal Flood', 'Fog'),
#  ('Coastal Flood', 'Haze'),
#  ('Coastal Flood', 'Polluted Air'),
#  ('Coastal Flood', 'Sand haze'),
#  ('Coastal Flood', 'Smoke'),
#  ('Coastal Flood', 'Ocean Acidification'),
#  ('Coastal Flood', 'Rogue Wave'),
#  ('Coastal Flood', 'Sea Water Intrusion'),
#  ('Coastal Flood', 'Sea Ice (Ice Bergs)'),
#  ('Coastal Flood', 'Ice Flow'),
#  ('Coastal Flood', 'Seiche'),
#  ('Coastal Flood', 'Storm Surge'),
#  ('Coastal Flood', 'Storm Tides'),
#  ('Coastal Flood', 'Tsunami'),
#  ('Coastal Flood', 'Depression or Cyclone (Low Pressure Area)'),
#  ('Coastal Flood', 'Extra-tropical Cyclone'),
#  ('Coastal Flood', 'Sub-Tropical Cyclone'),
#  ('Coastal Flood', 'Acid Rain'),
#  ('Coastal Flood', 'Blizzard'),
#  ('Coastal Flood', 'Drought'),
#  ('Coastal Flood', 'Hail'),
#  ('Coastal Flood', 'Ice Storm'),
#  ('Coastal Flood', 'Snow'),
#  ('Coastal Flood', 'Snow Storm'),
#  ('Coastal Flood', 'Cold Wave'),
#  ('Coastal Flood', 'Dzud'),
#  ('Coastal Flood', 'Freeze'),
#  ('Coastal Flood', 'Frost (Hoar Frost)'),
#  ('Coastal Flood', 'Freezing Rain (Supercooled Rain)'),
#  ('Coastal Flood', 'Glaze'),
#  ('Coastal Flood', 'Ground Frost'),
#  ('Coastal Flood', 'Heatwave'),
#  ('Coastal Flood', 'Icing (Including Ice)'),
#  ('Coastal Flood', 'Thaw'),
#  ('Coastal Flood', 'Avalanche'),
#  ('Coastal Flood', 'Mud Flow'),
#  ('Coastal Flood', 'Rock slide'),
#  ('Coastal Flood', 'Derecho'),
#  ('Coastal Flood', 'Gale (Strong Gale)'),
#  ('Coastal Flood', 'Squall'),
#  ('Coastal Flood', 'Subtropical Storm'),
#  ('Coastal Flood', 'Tropical Cyclone (Cyclonic Wind/ Rain Storm Surge)'),
#  ('Coastal Flood', 'Tropical Storm'),
#  ('Coastal Flood', 'Tornado'),
#  ('Coastal Flood', 'Wind'),
#  ('Coastal Flood', 'Airburst'),
#  ('Coastal Flood',
#   'Geomagnetic Storm (including energetic particles related to space weather, and solar flare radio blackout [R Scale])'),
#  ('Coastal Flood', 'UV Radiation'),
#  ('Coastal Flood', 'Meteorite Impact'),
#  ('Coastal Flood', 'Ionospheric Storms'),
#  ('Coastal Flood', 'Radio Blackout'),
#  ('Coastal Flood', 'Solar Storm (Solar Radiation Storm) (S Scale)'),
#  ('Coastal Flood', 'Space Hazard / Accident'),
#  ('Coastal Flood', 'Near-Earth Object'),
#  ('Coastal Flood', 'Earthquake'),
#  ('Coastal Flood', 'Ground Shaking (Earthquake)'),
#  ('Coastal Flood', 'Liquefaction (Earthquake Trigger)'),
#  ('Coastal Flood',
#   'Earthquake Surface Rupture, Fissures, and Tectonic Uplift/Subsidence'),
#  ('Coastal Flood',
#   'Subsidance and Uplift, Including Shoreline Change (Earthquake Trigger)'),
#  ('Coastal Flood', 'Tsunami (Earthquake Trigger)'),
#  ('Coastal Flood', 'Landslide or Debris Flow (Earthquake trigger)'),
#  ('Coastal Flood', 'Ground Gases (Seismogenic)'),
#  ('Coastal Flood', 'Lava Flows (Lava Domes)'),
#  ('Coastal Flood', 'Ash/Tephra Fall (Physical and Chemical)'),
#  ('Coastal Flood', 'Ballistics (Volcanic)'),
#  ('Coastal Flood', 'Pyroclastic Density Current'),
#  ('Coastal Flood', 'Debris Flow/Lahars/Floods'),
#  ('Coastal Flood', 'Landslide (Volcanic Trigger)'),
#  ('Coastal Flood', 'Ground Shaking (Volcanic Earthquake)'),
#  ('Coastal Flood', 'Volcanic Gases and Aerosols'),
#  ('Coastal Flood', 'Tsunami (Volcanic Trigger)'),
#  ('Coastal Flood', 'Lightning (Volcanic Trigger)'),
#  ('Coastal Flood', 'Urban Fire (During/Following Volcanic Eruption)'),
#  ('Coastal Flood',
#   'Subsidence and Uplift, Including Shoreline Change (Magmatic/Volcanic Trigger)'),
#  ('Coastal Flood',
#   'Ground Shaking (induced earthquake, reservoir fill, dams, cavity collapse, underground explosion, impact, hydrocarbon fields, shale exploration, etc.)'),
#  ('Coastal Flood', 'Liquefaction (Groundwater Trigger)'),
#  ('Coastal Flood', 'Ground Fissuring'),
#  ('Coastal Flood', 'Subsidence and Uplift Including Shoreline Change'),
#  ('Coastal Flood', 'Shrink-Swell Subsidence'),
#  ('Coastal Flood', 'Sinkhole'),
#  ('Coastal Flood', 'Ground Gases (CH4, Rn, etc.)'),
#  ('Coastal Flood', 'Riverbank Erosion'),
#  ('Coastal Flood', 'Sand Encroachment'),
#  ...]

# %% [markdown]
# ## Step 7: Record and update spreadsheets.

# %%
# store the scores and justifications in the new dataframes
i = 0
# missing_value contains the first pair that does not have a value stored, slice the pairs list to start from there
pairs = pairs[pairs.index(missing_value):]

for pair in pairs:
    data = run_llm(pair[0], pair[1], df[df['Hazard_Name'] == pair[0]]['Hazard_Description'].values[0], df[df['Hazard_Name'] == pair[1]]['Hazard_Description'].values[0])
    scores_df.loc[pair[0], pair[1]] = data[0]
    justification_df.loc[pair[0], pair[1]] = data[1]
    if i % 20 == 0:
      scores_df.to_excel("./out/scores.xlsx")
      justification_df.to_excel("./out/justifications.xlsx")
    i+=1
# Out:
# Running: Downburst, Sea Water Intrusion
#
#     Based on my training data, I would rate the likelihood of Downburst causing Sea Water Intrusion as a 3 - Likely. This is because downbursts can cause significant damage to coastal infrastructure and disrupt natural barriers that prevent seawater intrusion into freshwater aquifers. The strong winds and heavy
# Extracted Likelihood: 3.0
# ====================================
# Running: Downburst, Sea Ice (Ice Bergs)
#
#     Based on my training data and knowledge, I would rate the likelihood of Downburst causing Sea Ice (Ice Bergs) as a 2 - Unlikely. This is because downbursts are typically associated with severe thunderstorms that occur over land or near coastal areas, rather than in open ocean waters where sea ice forms.
# Extracted Likelihood: 2.0
# ====================================
# Running: Downburst, Ice Flow
#
#     Based on my training data, I would rate the likelihood of Downburst causing Ice Flow as a 2 - Unlikely. This is because downbursts are typically associated with warm air and heavy precipitation, which does not create ideal conditions for ice formation or flow. While it's possible that an intense downdraft could potentially cause some
# Extracted Likelihood: 2.0
# ====================================
# Running: Downburst, Seiche
#
#     Based on my training data and knowledge, I would rate the likelihood of Downburst causing Seiche as a 2 - Unlikely. This is because downbursts are typically associated with thunderstorms that occur over land or near coastal areas, rather than directly over open ocean waters where seiches can form. While it's
# Extracted Likelihood: 2.0
# ====================================
# Running: Downburst, Storm Surge
#
#     Based on my training data, I can provide information about the likelihood of various hazards causing specific outcomes. In this case, considering Downburst causes Storm Surge, I would rate the likelihood as follows:
#
#       - 2: Unlikely (Please explain)
#
#       The connection between a downburst and storm
# Extracted Likelihood: 2.0
# ====================================
# Running: Downburst, Storm Tides
#
#     Based on my training data and knowledge, I would rate the likelihood of Downburst causing Storm Tides as a 3 - Likely. This is because downbursts are known to cause strong winds that can lead to storm surges and coastal flooding, which in turn can result in storm tides. However, it's
# Extracted Likelihood: 3.0
# ====================================
# Running: Downburst, Tsunami
#
#     Based on my training data and knowledge, I would rate the likelihood of Downburst causing Tsunami as follows:
#       - Likely (3)
#
#       The association between downbursts and tsunamis is not direct. However, intense thunderstorms can generate strong winds that could potentially trigger a
# Extracted Likelihood: 3.0
# ====================================
# Running: Downburst, Depression or Cyclone (Low Pressure Area)
#
#     Based on my training data, I would rate the likelihood of Downburst causing Depression or Cyclone (Low Pressure Area) as a 4 - Very Likely. This is because downbursts are often associated with severe thunderstorms that can lead to low-pressure areas and depressions. The strong wind
# Extracted Likelihood: 4.0
# ====================================
# Running: Downburst, Extra-tropical Cyclone
#
#     Based on my training data, I would rate the likelihood of Downburst causing Extra-tropical Cyclone as 3 - Likely. This is because downbursts are often associated with severe thunderstorms, which can lead to the formation of extra-tropical cyclones. However, it's important to
# Extracted Likelihood: 3.0
# ====================================
# Running: Downburst, Sub-Tropical Cyclone
#
#     Based on the information provided, I would rate the likelihood of Downburst causing Sub-Tropical Cyclone as 3 - Likely. This is because downbursts are often associated with severe thunderstorms, which can lead to the formation of tropical cyclones. Additionally, sub-tropical cyclones are known to
# Extracted Likelihood: 3.0
# ====================================
# Running: Downburst, Acid Rain
#
#     Based on my knowledge, there is no direct relationship between Downburst and Acid Rain. However, I can provide some information that might be helpful for your assessment.
#
#     The formation of acid rain is primarily influenced by the presence of sulfur dioxide (SO2) and nitrogen oxides (NOx), which are em
# No likelihood score found.
# ====================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 7
#       4 pairs = pairs[pairs.index(missing_value):]
#       6 for pair in pairs:
# ----> 7     data = run_llm(pair[0], pair[1], df[df['Hazard_Name'] == pair[0]]['Hazard_Description'].values[0], df[df['Hazard_Name'] == pair[1]]['Hazard_Description'].values[0])
#       8     scores_df.loc[pair[0], pair[1]] = data[0]
#       9     justification_df.loc[pair[0], pair[1]] = data[1]
#
# Cell In[11], line 41, in run_llm(hazard1, hazard2, def1, def2)
#      19 prompt = f"""What is the likelihood that {hazard1} causes {hazard2}, bearing in mind:
#      20 {hazard1}: {def1}
#      21 {hazard2}: {def2}
#      22 """
#      24 super_prompt = f"""
#      25 SYSTEM: We're evaluating the likelihood of various hazards causing specific outcomes. Your responses should be one number between 0 and 5, following the below scale. Include a short explanation for your score, as it helps understand the reasoning behind your assessment.
#      26
#    (...)
#      38 ASSISTANT:
#      39 """
# ---> 41 response = llm(super_prompt)
#      42 print(f"Running: {hazard1}, {hazard2}")
#      43 print(response)
#
# File /cs/student/projects1/2022/wonjulee/natural-hazard-id/.env/lib64/python3.9/site-packages/ctransformers/llm.py:664, in LLM.__call__(self, prompt, max_new_tokens, top_k, top_p, temperature, repetition_penalty, last_n_tokens, seed, batch_size, threads, stop, stream, reset)
#     662 if stream:
#     663     return text
# --> 664 return "".join(text)
#
# File /cs/student/projects1/2022/wonjulee/natural-hazard-id/.env/lib64/python3.9/site-packages/ctransformers/llm.py:570, in LLM._stream(self, prompt, max_new_tokens, top_k, top_p, temperature, repetition_penalty, last_n_tokens, seed, batch_size, threads, stop, reset)
#     568 text = ""
#     569 incomplete = b""
# --> 570 for token in self.generate(
#     571     tokens,
#     572     top_k=top_k,
#     573     top_p=top_p,
#     574     temperature=temperature,
#     575     repetition_penalty=repetition_penalty,
#     576     last_n_tokens=last_n_tokens,
#     577     seed=seed,
#     578     batch_size=batch_size,
#     579     threads=threads,
#     580     reset=reset,
#     581 ):
#     582     # Handle incomplete UTF-8 multi-byte characters.
#     583     incomplete += self.detokenize([token], decode=False)
#     584     complete, incomplete = utf8_split_incomplete(incomplete)
#
# File /cs/student/projects1/2022/wonjulee/natural-hazard-id/.env/lib64/python3.9/site-packages/ctransformers/llm.py:537, in LLM.generate(self, tokens, top_k, top_p, temperature, repetition_penalty, last_n_tokens, seed, batch_size, threads, reset)
#     528 while True:
#     529     token = self.sample(
#     530         top_k=top_k,
#     531         top_p=top_p,
#    (...)
#     535         seed=seed,
#     536     )
# --> 537     self.eval([token], batch_size=batch_size, threads=threads)
#     538     if self.is_eos_token(token):
#     539         break
#
# File /cs/student/projects1/2022/wonjulee/natural-hazard-id/.env/lib64/python3.9/site-packages/ctransformers/llm.py:403, in LLM.eval(self, tokens, batch_size, threads)
#     399     logger.warning(
#     400         f"Number of tokens ({n_past + n_tokens}) exceeded maximum context length ({self.context_length})."
#     401     )
#     402 tokens = (c_int * n_tokens)(*tokens)
# --> 403 status = self.ctransformers_llm_batch_eval(
#     404     tokens,
#     405     n_tokens,
#     406     n_past,
#     407     batch_size,
#     408     threads,
#     409 )
#     410 if not status:
#     411     raise RuntimeError("Failed to evaluate tokens.")
#
# KeyboardInterrupt:

# %% [markdown]
# ## Step 8: Rerun all instances of -1, until there are no more -1's

# %%
def find_invalid_pairs():
    '''
    Finds pairs of row and column categories in the scores DataFrame where the corresponding element is -1

    Returns:
    - list: A list of tuples containing the row and column categories of the missing elements.
    '''
    scores_df = pd.read_excel("./out/scores.xlsx", index_col=0, dtype=str)
    
    # check which pairs are equal to -1
    invalid_pairs = []
    for i, row in scores_df.iterrows():
        for j, value in row.items():
            if value == "-1":
                invalid_pairs.append((i, j))
    
    return invalid_pairs

# %%
# add the invalid pairs to update score_df
j = 0
invalid_pairs = find_invalid_pairs()

# until no more invalid pairs
while invalid_pairs:
    for pair in invalid_pairs:
        data = run_llm(pair[0], pair[1], df[df['Hazard_Name'] == pair[0]]['Hazard_Description'].values[0], df[df['Hazard_Name'] == pair[1]]['Hazard_Description'].values[0])
        scores_df.loc[pair[0], pair[1]] = data[0]
        justification_df.loc[pair[0], pair[1]] = data[1]
        if j % 20 == 0:
            scores_df.to_excel("./out/scores.xlsx")
            justification_df.to_excel("./out/justifications.xlsx")
        j+=1
    # reset, and check again
    j = 0
    invalid_pairs = find_invalid_pairs()
# Out:
# Running: Downburst, Lightning (Electrical Storm)
#
#     Based on my training data and knowledge, I would rate the likelihood of Downburst causing Lightning (Electrical Storm) as 4 - Very Likely. This is because downbursts are often associated with severe thunderstorms, which can produce lightning. In fact, lightning is one of the primary dangers pos
# Extracted Likelihood: 4.0
# ====================================
# Running: Downburst, Thunderstorm
#
#     Based on the information provided, I would rate the likelihood that Downburst causes Thunderstorm as 4 (Very Likely). This is because downbursts are often associated with severe thunderstorms, and the violent downdrafts can lead to the formation of electrical discharges. The strong winds and
# Extracted Likelihood: 4.0
# ====================================
# Running: Downburst, Coastal Flood
#
#     Based on my training data, I would rate the likelihood of Downburst causing Coastal Flood as a 3 - Likely. This is because downbursts can generate strong surface winds that could potentially cause coastal flooding, especially if they occur during high tides or storm surges. However, it's worth noting
# Extracted Likelihood: 3.0
# ====================================
# Running: Downburst, Estuarine (Coastal) Flood
#
#     Based on my training data, I would rate the likelihood of Downburst causing Estuarine (Coastal) Flood as 4 - Very Likely. This is because downbursts are known to cause strong winds and storm surges that can lead to flooding in coastal areas. The combination of these two factors increases
# Extracted Likelihood: 4.0
# ====================================
# Running: Downburst, Flash Flood
#
#     Based on my training data, I would rate the likelihood of Downburst causing Flash Flood as a 4 - Very Likely. This is because downbursts are often associated with heavy rainfall and strong winds, which can lead to flash flooding. The short time interval between the observable causative event (the downburst
# Extracted Likelihood: 4.0
# ====================================
# Running: Downburst, Fluvial (Riverine) Flood
#
#     Based on my training data and knowledge, I would assign a likelihood score of 4 (Very Likely) for Downburst causing Fluvial (Riverine) Flood. This is because downbursts are known to cause intense rainfall and strong winds that can lead to flash flooding in nearby water bodies,
# Extracted Likelihood: 4.0
# ====================================
# Running: Downburst, Groundwater Flood
#
#     Based on my training data, I would rate the likelihood of Downburst causing Groundwater Flood as a 3 - Likely. This is because downbursts can cause significant surface runoff and erosion, which can lead to an increase in groundwater levels and potentially cause flooding. Additionally, the intense rainfall
# Extracted Likelihood: 3.0
# ====================================
# Running: Downburst, Ice-Jam Flood Including Debris
#
#     Based on the given information, I would rate the likelihood of Downburst causing Ice-Jam Flood Including Debris as a 4 (Very Likely). This is because downbursts are known to cause significant damage and can easily dislodge ice cakes and other debris, leading to an increased risk of flo
# Extracted Likelihood: 4.0
# ====================================
# Running: Downburst, Ponding (Drainage) Flood
#
#     Based on my training data, I would rate the likelihood of Downburst causing Ponding (Drainage) Flood as a 4 - Very Likely. This is because downbursts are known to cause intense rainfall and strong winds that can overwhelm drainage systems, leading to ponding flo
# Extracted Likelihood: 4.0
# ====================================
# Running: Downburst, Snowmelt Flood
#
#     Based on my training data, I would rate the likelihood of Downburst causing Snowmelt Flood as a 3 - Likely. This is because downbursts can cause significant melting of snowpack by warming the air and ground surface, leading to increased runoff and flooding in nearby rivers. However, it's important
# Extracted Likelihood: 3.0
# ====================================
# Running: Downburst, Surface Water Flooding
#
#     Based on my training data, I would rate the likelihood of Downburst causing Surface Water Flooding as a 4 - Very Likely. This is because downbursts are often associated with heavy rainfall and strong winds that can cause surface water flooding. The intense rain and powerful gusts can overwhelm d
# Extracted Likelihood: 4.0
# ====================================
# Running: Downburst, Glacial Lake Outburst Flood
#
#     Based on my training data, I would rate the likelihood of Downburst causing Glacial Lake Outburst Flood as a 3 - Likely. This is because downbursts can potentially trigger the sudden release of water from glacial lakes by creating an overflow or breaching the lake's natural dam. However, this outcome is
# Extracted Likelihood: 3.0
# ====================================
# Running: Downburst, Black Carbon (Brown Clouds)
#
#     Based on my training data, I would rate the likelihood of Downburst causing Black Carbon (Brown Clouds) as a 3 - Likely. This is because downbursts are known to cause strong winds and turbulence, which can pick up and transport particulate matter like black carbon into the atmosphere. Additionally, dow
# Extracted Likelihood: 3.0
# ====================================
# Running: Downburst, Dust storm or Sandstorm
#
#     Based on the given information, I would rate the likelihood of Downburst causing Dust storm or Sandstorm as 4 (Very Likely). This is because downbursts are often associated with severe thunderstorms, which can generate strong winds that easily lift dust and sand particles into the air. Additionally, downd
# Extracted Likelihood: 4.0
# ====================================
# Running: Downburst, Fog
#
#     Based on my training data and knowledge, I would rate the likelihood of Downburst causing Fog as a 2 - Unlikely. This is because downbursts are typically associated with strong winds and turbulence, which can disrupt fog formation by mixing the air and preventing the accumulation of water droplets. However, there
# Extracted Likelihood: 2.0
# ====================================
# Running: Downburst, Haze
#
#     Based on my training data, I would rate the likelihood of Downburst causing Haze as a 3 - Likely. This is because downbursts are known to cause strong winds and turbulence, which can pick up and suspend small particles in the air, leading to haze conditions. The relationship between downbursts
# Extracted Likelihood: 3.0
# ====================================
# Running: Downburst, Polluted Air
#
#      Based on the given information, I would rate the likelihood of Downburst causing Polluted Air as a 4 - Very Likely. This is because downbursts are often associated with severe thunderstorms that can generate strong winds and turbulence, which could potentially pick up and suspend pollutants in the air
# Extracted Likelihood: 4.0
# ====================================
# Running: Downburst, Sand haze
#
#     Based on my training data and knowledge, I would rate the likelihood of Downburst causing Sand haze as follows:
#
#     3 - Likely.
#
#     The reasoning behind this rating is that a downburst can pick up loose sand or dust particles from the ground surface and suspend them in the air, creating hazy
# Extracted Likelihood: 3.0
# ====================================
# Running: Downburst, Smoke
#
#     Based on my training data and knowledge, I would rate the likelihood of Downburst causing Smoke as follows:
#       Likelihood Score: 3 (Likely)
#       Explanation: Severe thunderstorms associated with downbursts often generate strong winds that can spread burning materials or ignite vegetation
# Extracted Likelihood: 3.0
# ====================================
# Running: Downburst, Ocean Acidification
#
#     Based on my knowledge, there is no direct relationship between Downburst and Ocean Acidification. The likelihood of Downburst causing Ocean Acidification is very low (0). While downbursts can cause localized damage to coastal areas, they do not directly affect the ocean's chemistry or pH levels.
#
#
# Extracted Likelihood: 0.0
# ====================================
# Running: Downburst, Rogue Wave
#
#     Based on my training data, I would rate the likelihood of Downburst causing Rogue Wave as a 3 - Likely. This is because downbursts are known to cause powerful wind gusts that can generate large waves and increase their height, leading to rogue waves in some cases. However, it's not a certain
# Extracted Likelihood: 3.0
# ====================================
# Running: Downburst, Sea Water Intrusion
#
#     Based on my training data, I would rate the likelihood of Downburst causing Sea Water Intrusion as follows:
#
#     3 - Likely.
#
#     Here's why:
#
#     Severe thunderstorms associated with downbursts can cause significant damage to coastal infrastructure and disrupt
# Extracted Likelihood: 3.0
# ====================================
