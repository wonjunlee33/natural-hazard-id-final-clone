# %% [markdown]
# # Associated Hazard Extractor
# Used to combine the association matrix with the main hazard definitions DF to slot associations into 'Upstream Hazards'.

# %% [markdown]
# ## Step 1: Get Requirements

# %%
import pandas as pd

# %% [markdown]
# ## Step 2: Open data/scores.xlsx.
# This contains the full 2D association matrix, 303 x 303; the first row and column are the names of the hazards. The cells contain the scores of the hazards. The scores are the result of prompting an LLM to generate the associations.

# %%
df = pd.read_excel('scores.xlsx')
df = df.set_index('Unnamed: 0')
df
# Out:
#                                          Downburst  \
# Unnamed: 0
# Downburst                                      NaN
# Lightning (Electrical Storm)                   4.0
# Thunderstorm                                  -1.0
# Coastal Flood                                 -1.0
# Estuarine (Coastal) Flood                      3.0
# ...                                            ...
# Explosive Remnants of War                      4.0
# Environmental Degradation from Conflict        4.0
# Violence                                       4.0
# Stampede or Crushing (Human)                   3.0
# Financial shock                                4.0
#
#                                          Lightning (Electrical Storm)  \
# Unnamed: 0
# Downburst                                                         4.0
# Lightning (Electrical Storm)                                      NaN
# Thunderstorm                                                      4.0
# Coastal Flood                                                     3.0
# Estuarine (Coastal) Flood                                         3.0
# ...                                                               ...
# Explosive Remnants of War                                         3.0
# Environmental Degradation from Conflict                           4.0
# Violence                                                          1.0
# Stampede or Crushing (Human)                                      2.0
# Financial shock                                                   0.0
#
#                                          Thunderstorm  Coastal Flood  \
# Unnamed: 0
# Downburst                                         4.0            4.0
# Lightning (Electrical Storm)                      5.0            1.0
# Thunderstorm                                      NaN            3.0
# Coastal Flood                                     3.0            NaN
# Estuarine (Coastal) Flood                         3.0            4.0
# ...                                               ...            ...
# Explosive Remnants of War                         2.0            3.0
# Environmental Degradation from Conflict           3.0            4.0
# Violence                                          0.0            2.0
# Stampede or Crushing (Human)                      2.0            3.0
# Financial shock                                   2.0            3.0
#
#                                          Estuarine (Coastal) Flood  \
# Unnamed: 0
# Downburst                                                      4.0
# Lightning (Electrical Storm)                                   4.0
# Thunderstorm                                                   4.0
# Coastal Flood                                                  4.0
# Estuarine (Coastal) Flood                                      NaN
# ...                                                            ...
# Explosive Remnants of War                                      3.0
# Environmental Degradation from Conflict                        4.0
# Violence                                                       3.0
# Stampede or Crushing (Human)                                   2.0
# Financial shock                                                3.0
#
#                                          Flash Flood  \
# Unnamed: 0
# Downburst                                        4.0
# Lightning (Electrical Storm)                     3.0
# Thunderstorm                                     4.0
# Coastal Flood                                    3.0
# Estuarine (Coastal) Flood                        3.0
# ...                                              ...
# Explosive Remnants of War                        2.0
# Environmental Degradation from Conflict          4.0
# Violence                                         2.0
# Stampede or Crushing (Human)                     2.0
# Financial shock                                  2.0
#
#                                          Fluvial (Riverine) Flood  \
# Unnamed: 0
# Downburst                                                     4.0
# Lightning (Electrical Storm)                                  4.0
# Thunderstorm                                                  4.0
# Coastal Flood                                                 3.0
# Estuarine (Coastal) Flood                                     3.0
# ...                                                           ...
# Explosive Remnants of War                                     3.0
# Environmental Degradation from Conflict                       4.0
# Violence                                                      3.0
# Stampede or Crushing (Human)                                  2.0
# Financial shock                                               3.0
#
#                                          Groundwater Flood  \
# Unnamed: 0
# Downburst                                              3.0
# Lightning (Electrical Storm)                          -1.0
# Thunderstorm                                           4.0
# Coastal Flood                                          4.0
# Estuarine (Coastal) Flood                              4.0
# ...                                                    ...
# Explosive Remnants of War                              4.0
# Environmental Degradation from Conflict                4.0
# Violence                                               0.0
# Stampede or Crushing (Human)                           3.0
# Financial shock                                       -1.0
#
#                                          Ice-Jam Flood Including Debris  \
# Unnamed: 0
# Downburst                                                           4.0
# Lightning (Electrical Storm)                                        4.0
# Thunderstorm                                                        3.0
# Coastal Flood                                                       4.0
# Estuarine (Coastal) Flood                                           4.0
# ...                                                                 ...
# Explosive Remnants of War                                           4.0
# Environmental Degradation from Conflict                             4.0
# Violence                                                            4.0
# Stampede or Crushing (Human)                                        3.0
# Financial shock                                                     4.0
#
#                                          Ponding (Drainage) Flood  ...  \
# Unnamed: 0                                                         ...
# Downburst                                                     4.0  ...
# Lightning (Electrical Storm)                                  4.0  ...
# Thunderstorm                                                  1.0  ...
# Coastal Flood                                                 4.0  ...
# Estuarine (Coastal) Flood                                     4.0  ...
# ...                                                           ...  ...
# Explosive Remnants of War                                     4.0  ...
# Environmental Degradation from Conflict                       4.0  ...
# Violence                                                      4.0  ...
# Stampede or Crushing (Human)                                  1.0  ...
# Financial shock                                               4.0  ...
#
#                                          Road Traffic Accident  \
# Unnamed: 0
# Downburst                                                  3.0
# Lightning (Electrical Storm)                               2.0
# Thunderstorm                                               1.0
# Coastal Flood                                              2.0
# Estuarine (Coastal) Flood                                  3.0
# ...                                                        ...
# Explosive Remnants of War                                  3.0
# Environmental Degradation from Conflict                    3.0
# Violence                                                   4.0
# Stampede or Crushing (Human)                               3.0
# Financial shock                                            NaN
#
#                                          Explosive agents  \
# Unnamed: 0
# Downburst                                             3.0
# Lightning (Electrical Storm)                          4.0
# Thunderstorm                                          3.0
# Coastal Flood                                         2.0
# Estuarine (Coastal) Flood                             2.0
# ...                                                   ...
# Explosive Remnants of War                             4.0
# Environmental Degradation from Conflict               4.0
# Violence                                              4.0
# Stampede or Crushing (Human)                          1.0
# Financial shock                                       NaN
#
#                                          International Armed Conflict (IAC)  \
# Unnamed: 0
# Downburst                                                               2.0
# Lightning (Electrical Storm)                                            1.0
# Thunderstorm                                                            1.0
# Coastal Flood                                                           2.0
# Estuarine (Coastal) Flood                                               2.0
# ...                                                                     ...
# Explosive Remnants of War                                               4.0
# Environmental Degradation from Conflict                                 4.0
# Violence                                                                4.0
# Stampede or Crushing (Human)                                            3.0
# Financial shock                                                         NaN
#
#                                          Non-International Armed Conflict (NIAC)  \
# Unnamed: 0
# Downburst                                                                    3.0
# Lightning (Electrical Storm)                                                 2.0
# Thunderstorm                                                                 2.0
# Coastal Flood                                                                3.0
# Estuarine (Coastal) Flood                                                    2.0
# ...                                                                          ...
# Explosive Remnants of War                                                    4.0
# Environmental Degradation from Conflict                                      4.0
# Violence                                                                     4.0
# Stampede or Crushing (Human)                                                 3.0
# Financial shock                                                              NaN
#
#                                          Civil Unrest  \
# Unnamed: 0
# Downburst                                         3.0
# Lightning (Electrical Storm)                      2.0
# Thunderstorm                                      3.0
# Coastal Flood                                     3.0
# Estuarine (Coastal) Flood                         3.0
# ...                                               ...
# Explosive Remnants of War                         4.0
# Environmental Degradation from Conflict           4.0
# Violence                                          4.0
# Stampede or Crushing (Human)                      3.0
# Financial shock                                   NaN
#
#                                          Explosive Remnants of War  \
# Unnamed: 0
# Downburst                                                      3.0
# Lightning (Electrical Storm)                                   3.0
# Thunderstorm                                                   3.0
# Coastal Flood                                                  3.0
# Estuarine (Coastal) Flood                                      2.0
# ...                                                            ...
# Explosive Remnants of War                                      NaN
# Environmental Degradation from Conflict                        4.0
# Violence                                                       4.0
# Stampede or Crushing (Human)                                   1.0
# Financial shock                                                NaN
#
#                                          Environmental Degradation from Conflict  \
# Unnamed: 0
# Downburst                                                                    4.0
# Lightning (Electrical Storm)                                                -1.0
# Thunderstorm                                                                 3.0
# Coastal Flood                                                                3.0
# Estuarine (Coastal) Flood                                                    4.0
# ...                                                                          ...
# Explosive Remnants of War                                                    4.0
# Environmental Degradation from Conflict                                      NaN
# Violence                                                                     4.0
# Stampede or Crushing (Human)                                                 1.0
# Financial shock                                                              NaN
#
#                                          Violence  \
# Unnamed: 0
# Downburst                                     2.0
# Lightning (Electrical Storm)                  1.0
# Thunderstorm                                  3.0
# Coastal Flood                                 2.0
# Estuarine (Coastal) Flood                     2.0
# ...                                           ...
# Explosive Remnants of War                     4.0
# Environmental Degradation from Conflict       4.0
# Violence                                      NaN
# Stampede or Crushing (Human)                  4.0
# Financial shock                               NaN
#
#                                          Stampede or Crushing (Human)  \
# Unnamed: 0
# Downburst                                                         4.0
# Lightning (Electrical Storm)                                      4.0
# Thunderstorm                                                      3.0
# Coastal Flood                                                     4.0
# Estuarine (Coastal) Flood                                         4.0
# ...                                                               ...
# Explosive Remnants of War                                         4.0
# Environmental Degradation from Conflict                           4.0
# Violence                                                          4.0
# Stampede or Crushing (Human)                                      NaN
# Financial shock                                                   NaN
#
#                                          Financial shock
# Unnamed: 0
# Downburst                                            3.0
# Lightning (Electrical Storm)                         1.0
# Thunderstorm                                         3.0
# Coastal Flood                                        4.0
# Estuarine (Coastal) Flood                            4.0
# ...                                                  ...
# Explosive Remnants of War                            4.0
# Environmental Degradation from Conflict              4.0
# Violence                                             4.0
# Stampede or Crushing (Human)                         3.0
# Financial shock                                      NaN
#
# [302 rows x 302 columns]

# %% [markdown]
# ## Step 3: Transform the 2D matrix into a 1D array of tuples, where each tuple contains the name of the hazard and the association score.

# %%
data = []
for index, row in df.iterrows():
    for column in df.columns:
        data.append((index, column, row[column]))

data[:5]
# Out:
# [('Downburst', 'Downburst', nan),
#  ('Downburst', 'Lightning (Electrical Storm)', 4.0),
#  ('Downburst', 'Thunderstorm', 4.0),
#  ('Downburst', 'Coastal Flood', 4.0),
#  ('Downburst', 'Estuarine (Coastal) Flood', 4.0)]

# %% [markdown]
# ## Step 4: Create a DF from the 1D array.
# We will drop any rows with a score of less than 4, as we correlate any score less than 4 to be a non association.

# %%
scores_df = pd.DataFrame(data, columns=['hazard1', 'hazard2', 'score'])
scores_df
# Out:
#                hazard1                                  hazard2  score
# 0            Downburst                                Downburst    NaN
# 1            Downburst             Lightning (Electrical Storm)    4.0
# 2            Downburst                             Thunderstorm    4.0
# 3            Downburst                            Coastal Flood    4.0
# 4            Downburst                Estuarine (Coastal) Flood    4.0
# ...                ...                                      ...    ...
# 91199  Financial shock                Explosive Remnants of War    NaN
# 91200  Financial shock  Environmental Degradation from Conflict    NaN
# 91201  Financial shock                                 Violence    NaN
# 91202  Financial shock             Stampede or Crushing (Human)    NaN
# 91203  Financial shock                          Financial shock    NaN
#
# [91204 rows x 3 columns]

# %%
# Drop all rows with a score less than 4
scores_df = scores_df[scores_df['score'] >= 4]
scores_df
# Out:
#                         hazard1                               hazard2  score
# 82277                      Fire                               Mercury    5.0
# 20908                Earthquake           Ground Shaking (Earthquake)    5.0
# 5402               Polluted Air                             Pollution    5.0
# 82294                      Fire                              Methanol    5.0
# 61782           Measles (Human)  Vaccine-Preventable Diseases (Human)    5.0
# ...                         ...                                   ...    ...
# 49136  Antimicrobial Resistance                       Malaria (Human)    4.0
# 49142  Antimicrobial Resistance                     Monkeypox (Human)    4.0
# 49135  Antimicrobial Resistance                        Dengue (Human)    4.0
# 49130  Antimicrobial Resistance                     Pertussis (Human)    4.0
# 49127  Antimicrobial Resistance                    Diphtheria (Human)    4.0
#
# [14752 rows x 3 columns]

# %% [markdown]
# ## Step 5: Open the main hazard_definitions spreadsheet.
# We will then insert all the hazard associations of score larger or equal to 4 to the Upstream_Hazards column.

# %%
hazard_definitions = pd.read_excel("data/hazard_definitions.xlsx")
hazard_definitions
# Out:
#     Hazard_Code                  Hazard_Category  Hazard_Subcategory  \
# 0        MH0001  METEOROLOGICAL AND HYDROLOGICAL  Convective-Related
# 1        MH0002  METEOROLOGICAL AND HYDROLOGICAL  Convective-Related
# 2        MH0003  METEOROLOGICAL AND HYDROLOGICAL  Convective-Related
# 3        MH0004  METEOROLOGICAL AND HYDROLOGICAL               Flood
# 4        MH0005  METEOROLOGICAL AND HYDROLOGICAL               Flood
# ..          ...                              ...                 ...
# 297      SO0004                         SOCIETAL       Post-Conflict
# 298      SO0005                         SOCIETAL       Post-Conflict
# 299      SO0006                         SOCIETAL         Behavioural
# 300      SO0007                         SOCIETAL         Behavioural
# 301      SO0008                         SOCIETAL            Economic
#
#                                  Hazard_Name  \
# 0                                  Downburst
# 1               Lightning (Electrical Storm)
# 2                               Thunderstorm
# 3                              Coastal Flood
# 4                  Estuarine (Coastal) Flood
# ..                                       ...
# 297                Explosive Remnants of War
# 298  Environmental Degradation from Conflict
# 299                                 Violence
# 300             Stampede or Crushing (Human)
# 301                          Financial shock
#
#                                     Hazard_Description Upstream_Hazards  \
# 0    Downburst A downburst is a violent and damagin...              NaN
# 1    Lightning Lightning is the luminous manifestat...              NaN
# 2    Thunderstorm A thunderstorm is defined as one ...           MH0002
# 3    Coastal Flood Coastal flooding is most frequen...              NaN
# 4    Estuarine Flood Estuarine flooding is flooding...           MH0004
# ..                                                 ...              ...
# 297  Explosive Remnants of War Explosive remnants o...           SO0003
# 298  Environmental Degradation from Conflict Enviro...           SO0003
# 299  Violence Violence refers to the intentional or...           SO0003
# 300  Stampede or Crushing Stampede or crushing is t...           SO0003
# 301  Financial shock A financial shock is an unexpe...           SO0003
#
#     Excluded_Hazards                                           Synonyms  \
# 0                NaN                  Microburst, Macroburst, Wind Sear
# 1                NaN  Bolt, Thunderbolt, Bolt-from-the-blue, Firebol...
# 2                NaN                                                NaN
# 3                NaN                    Storm Surge, Coastal inundation
# 4                NaN                  Flood, Flooding, Coastal flooding
# ..               ...                                                ...
# 297              NaN  Unexploded ordnance, Abandoned explosive ordnance
# 298              NaN       Ecological degradation, Environmental damage
# 299              NaN                                                NaN
# 300              NaN                  Crush, Mass panic, Crowd disaster
# 301              NaN  Financial crisis, Bank run, Banking crisis, Cu...
#
#                      Keywords Keywords_Operator  \
# 0                        Wind                OR
# 1            Lightning, storm                OR
# 2                       storm                OR
# 3                       Flood                OR
# 4                       river                OR
# ..                        ...               ...
# 297  explosive, crater, mines               AND
# 298            pollution, war               AND
# 299                  violence                OR
# 300        stampede, crushing                OR
# 301  financial, poor, economy                OR
#
#                                              Questions
# 0                               Did a downburst occur?
# 1                                 Was there lightning?
# 2                            Was there a thunderstorm?
# 3                Did the even take place at the coast?
# 4    Was the river flooding caused by coastal flood...
# ..                                                 ...
# 297  Were there any reports of explosive remnants o...
# 298  Were there any reports of environmental degrad...
# 299                Were there any reports of violence?
# 300    Were there any reports of stampede or crushing?
# 301  Were there any reports of financial shock, suc...
#
# [302 rows x 11 columns]

# %%
for pair in scores_df.itertuples():
    hazard1 = hazard_definitions[hazard_definitions["Hazard_Name"] == pair.hazard1]
    hazard2 = hazard_definitions[hazard_definitions["Hazard_Name"] == pair.hazard2]
    if len(hazard1) > 0 and len(hazard2) > 0:
        hazard1_id = hazard1["Hazard_Code"].values[0]
        hazard2_id = hazard2["Hazard_Code"].values[0]
        # Add the hazard2_id to the hazard1 row Upstream_Hazards column
        if hazard1["Upstream_Hazards"].values[0] == "None":
            hazard_definitions.loc[hazard_definitions["Hazard_Name"] == pair.hazard1, "Upstream_Hazards"] = hazard2_id
        else:
            hazard_definitions.loc[hazard_definitions["Hazard_Name"] == pair.hazard1, "Upstream_Hazards"] += ", " + hazard2_id

hazard_definitions
# Out:
#     Hazard_Code                  Hazard_Category  Hazard_Subcategory  \
# 0        MH0001  METEOROLOGICAL AND HYDROLOGICAL  Convective-Related
# 1        MH0002  METEOROLOGICAL AND HYDROLOGICAL  Convective-Related
# 2        MH0003  METEOROLOGICAL AND HYDROLOGICAL  Convective-Related
# 3        MH0004  METEOROLOGICAL AND HYDROLOGICAL               Flood
# 4        MH0005  METEOROLOGICAL AND HYDROLOGICAL               Flood
# ..          ...                              ...                 ...
# 297      SO0004                         SOCIETAL       Post-Conflict
# 298      SO0005                         SOCIETAL       Post-Conflict
# 299      SO0006                         SOCIETAL         Behavioural
# 300      SO0007                         SOCIETAL         Behavioural
# 301      SO0008                         SOCIETAL            Economic
#
#                                  Hazard_Name  \
# 0                                  Downburst
# 1               Lightning (Electrical Storm)
# 2                               Thunderstorm
# 3                              Coastal Flood
# 4                  Estuarine (Coastal) Flood
# ..                                       ...
# 297                Explosive Remnants of War
# 298  Environmental Degradation from Conflict
# 299                                 Violence
# 300             Stampede or Crushing (Human)
# 301                          Financial shock
#
#                                     Hazard_Description  \
# 0    Downburst A downburst is a violent and damagin...
# 1    Lightning Lightning is the luminous manifestat...
# 2    Thunderstorm A thunderstorm is defined as one ...
# 3    Coastal Flood Coastal flooding is most frequen...
# 4    Estuarine Flood Estuarine flooding is flooding...
# ..                                                 ...
# 297  Explosive Remnants of War Explosive remnants o...
# 298  Environmental Degradation from Conflict Enviro...
# 299  Violence Violence refers to the intentional or...
# 300  Stampede or Crushing Stampede or crushing is t...
# 301  Financial shock A financial shock is an unexpe...
#
#                                       Upstream_Hazards Excluded_Hazards  \
# 0                                                  NaN              NaN
# 1                                                  NaN              NaN
# 2    MH0002, MH0002, MH0005, MH0006, MH0007, MH0008...              NaN
# 3                                                  NaN              NaN
# 4    MH0004, EN0015, EN0016, BI0007, EN0010, MH0012...              NaN
# ..                                                 ...              ...
# 297  SO0003, MH0008, MH0023, MH0020, MH0019, MH0018...              NaN
# 298  SO0003, BI0027, BI0028, BI0030, TL0031, TL0028...              NaN
# 299  SO0003, TL0038, SO0008, SO0007, SO0005, SO0004...              NaN
# 300  SO0003, BI0007, CH0024, CH0020, CH0013, CH0008...              NaN
# 301  SO0003, GH0024, CH0024, CH0008, CH0007, CH0005...              NaN
#
#                                               Synonyms  \
# 0                    Microburst, Macroburst, Wind Sear
# 1    Bolt, Thunderbolt, Bolt-from-the-blue, Firebol...
# 2                                                  NaN
# 3                      Storm Surge, Coastal inundation
# 4                    Flood, Flooding, Coastal flooding
# ..                                                 ...
# 297  Unexploded ordnance, Abandoned explosive ordnance
# 298       Ecological degradation, Environmental damage
# 299                                                NaN
# 300                  Crush, Mass panic, Crowd disaster
# 301  Financial crisis, Bank run, Banking crisis, Cu...
#
#                      Keywords Keywords_Operator  \
# 0                        Wind                OR
# 1            Lightning, storm                OR
# 2                       storm                OR
# 3                       Flood                OR
# 4                       river                OR
# ..                        ...               ...
# 297  explosive, crater, mines               AND
# 298            pollution, war               AND
# 299                  violence                OR
# 300        stampede, crushing                OR
# 301  financial, poor, economy                OR
#
#                                              Questions
# 0                               Did a downburst occur?
# 1                                 Was there lightning?
# 2                            Was there a thunderstorm?
# 3                Did the even take place at the coast?
# 4    Was the river flooding caused by coastal flood...
# ..                                                 ...
# 297  Were there any reports of explosive remnants o...
# 298  Were there any reports of environmental degrad...
# 299                Were there any reports of violence?
# 300    Were there any reports of stampede or crushing?
# 301  Were there any reports of financial shock, suc...
#
# [302 rows x 11 columns]

# %% [markdown]
# ## Step 6: Update the hazard_definitions spreadsheet and save it to data folder.

# %%
hazard_definitions.to_excel("data/hazard_definitions_updated.xlsx", index=False)
